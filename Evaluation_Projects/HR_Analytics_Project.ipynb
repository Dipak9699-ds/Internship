# %% [markdown]
# # Import the libraries.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the dataset.

# %%
import pandas as pd
df = pd.read_csv(r'C:/Users/dipak/Downloads/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
#Get the numbers of rows and columns.
df.shape
# Out:
# (1470, 35)

# %%
#Check column of the dataframe.
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#Get the column datatypes.
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
#Get a count of the empty values for each column.
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
#Check any missing/null values in the dataset.
df.isnull().values.any()
# Out:
# False

# %%
#Checking for null values using heatmap.
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Basic information about dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# # Data Analysis and Visualization

# %%
#summary statistics.
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_5802d_row0_col0, #T_5802d_row0_col2, #T_5802d_row0_col3, #T_5802d_row0_col4, #T_5802d_row0_col6, #T_5802d_row0_col7, #T_5802d_row0_col8, #T_5802d_row0_col9, #T_5802d_row0_col10, #T_5802d_row0_col13, #T_5802d_row0_col14, #T_5802d_row0_col15, #T_5802d_row0_col16, #T_5802d_row0_col17, #T_5802d_row0_col18, #T_5802d_row0_col19, #T_5802d_row0_col20, #T_5802d_row0_col21, #T_5802d_row0_col22, #T_5802d_row0_col23, #T_5802d_row0_col24, #T_5802d_row0_col25, #T_5802d_row7_col1, #T_5802d_row7_col5, #T_5802d_row7_col11, #T_5802d_row7_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5802d_row0_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_5802d_row0_col5 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_5802d_row0_col11, #T_5802d_row3_col12, #T_5802d_row7_col19, #T_5802d_row7_col22 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_5802d_row0_col12, #T_5802d_row1_col3, #T_5802d_row1_col4, #T_5802d_row1_col6, #T_5802d_row1_col8, #T_5802d_row1_col9, #T_5802d_row1_col10, #T_5802d_row1_col13, #T_5802d_row1_col15, #T_5802d_row1_col16, #T_5802d_row1_col18, #T_5802d_row1_col20, #T_5802d_row1_col21, #T_5802d_row1_col23, #T_5802d_row1_col24, #T_5802d_row1_col25, #T_5802d_row2_col0, #T_5802d_row2_col3, #T_5802d_row2_col4, #T_5802d_row2_col6, #T_5802d_row2_col7, #T_5802d_row2_col8, #T_5802d_row2_col9, #T_5802d_row2_col10, #T_5802d_row2_col13, #T_5802d_row2_col14, #T_5802d_row2_col15, #T_5802d_row2_col16, #T_5802d_row2_col17, #T_5802d_row2_col18, #T_5802d_row2_col20, #T_5802d_row2_col21, #T_5802d_row2_col23, #T_5802d_row2_col24, #T_5802d_row2_col25, #T_5802d_row3_col1, #T_5802d_row3_col2, #T_5802d_row3_col3, #T_5802d_row3_col4, #T_5802d_row3_col5, #T_5802d_row3_col6, #T_5802d_row3_col8, #T_5802d_row3_col9, #T_5802d_row3_col10, #T_5802d_row3_col11, #T_5802d_row3_col13, #T_5802d_row3_col15, #T_5802d_row3_col16, #T_5802d_row3_col18, #T_5802d_row3_col19, #T_5802d_row3_col20, #T_5802d_row3_col21, #T_5802d_row3_col22, #T_5802d_row3_col23, #T_5802d_row3_col24, #T_5802d_row3_col25, #T_5802d_row4_col2, #T_5802d_row4_col3, #T_5802d_row4_col4, #T_5802d_row4_col6, #T_5802d_row4_col8, #T_5802d_row4_col9, #T_5802d_row4_col10, #T_5802d_row4_col13, #T_5802d_row4_col15, #T_5802d_row4_col16, #T_5802d_row4_col18, #T_5802d_row4_col20, #T_5802d_row4_col21, #T_5802d_row4_col22, #T_5802d_row4_col23, #T_5802d_row4_col24, #T_5802d_row4_col25, #T_5802d_row5_col3, #T_5802d_row5_col4, #T_5802d_row5_col6, #T_5802d_row5_col8, #T_5802d_row5_col9, #T_5802d_row5_col10, #T_5802d_row5_col13, #T_5802d_row5_col15, #T_5802d_row5_col16, #T_5802d_row5_col18, #T_5802d_row5_col20, #T_5802d_row5_col21, #T_5802d_row5_col22, #T_5802d_row5_col23, #T_5802d_row5_col24, #T_5802d_row5_col25, #T_5802d_row6_col3, #T_5802d_row6_col4, #T_5802d_row6_col6, #T_5802d_row6_col8, #T_5802d_row6_col9, #T_5802d_row6_col10, #T_5802d_row6_col13, #T_5802d_row6_col15, #T_5802d_row6_col16, #T_5802d_row6_col18, #T_5802d_row6_col20, #T_5802d_row6_col21, #T_5802d_row6_col24, #T_5802d_row7_col3, #T_5802d_row7_col4, #T_5802d_row7_col6, #T_5802d_row7_col8, #T_5802d_row7_col9, #T_5802d_row7_col10, #T_5802d_row7_col15, #T_5802d_row7_col16, #T_5802d_row7_col18, #T_5802d_row7_col21 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5802d_row1_col0, #T_5802d_row4_col0, #T_5802d_row4_col7, #T_5802d_row5_col0, #T_5802d_row7_col2, #T_5802d_row7_col14, #T_5802d_row7_col23 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_5802d_row1_col1, #T_5802d_row1_col12, #T_5802d_row5_col1, #T_5802d_row5_col12 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_5802d_row1_col2, #T_5802d_row1_col19, #T_5802d_row1_col22, #T_5802d_row2_col2, #T_5802d_row2_col19, #T_5802d_row2_col22, #T_5802d_row3_col0, #T_5802d_row3_col7, #T_5802d_row3_col14, #T_5802d_row4_col14, #T_5802d_row4_col19, #T_5802d_row5_col2, #T_5802d_row5_col14, #T_5802d_row5_col19, #T_5802d_row6_col22, #T_5802d_row6_col23, #T_5802d_row6_col25, #T_5802d_row7_col13, #T_5802d_row7_col20 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_5802d_row1_col5, #T_5802d_row5_col5 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_5802d_row1_col7, #T_5802d_row5_col7, #T_5802d_row7_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_5802d_row1_col11, #T_5802d_row2_col5 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_5802d_row1_col14, #T_5802d_row6_col2, #T_5802d_row6_col14, #T_5802d_row6_col19, #T_5802d_row7_col24, #T_5802d_row7_col25 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_5802d_row1_col17, #T_5802d_row3_col17, #T_5802d_row4_col17, #T_5802d_row5_col17, #T_5802d_row6_col17, #T_5802d_row7_col7, #T_5802d_row7_col17 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5802d_row2_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_5802d_row2_col11 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_5802d_row2_col12 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_5802d_row4_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_5802d_row4_col5 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_5802d_row4_col11 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_5802d_row4_col12 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_5802d_row5_col11 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_5802d_row6_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_5802d_row6_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_5802d_row6_col5 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_5802d_row6_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_5802d_row6_col11 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_5802d_row6_col12 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5802d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >DailyRate</th>
#       <th class="col_heading level0 col2" >DistanceFromHome</th>
#       <th class="col_heading level0 col3" >Education</th>
#       <th class="col_heading level0 col4" >EmployeeCount</th>
#       <th class="col_heading level0 col5" >EmployeeNumber</th>
#       <th class="col_heading level0 col6" >EnvironmentSatisfaction</th>
#       <th class="col_heading level0 col7" >HourlyRate</th>
#       <th class="col_heading level0 col8" >JobInvolvement</th>
#       <th class="col_heading level0 col9" >JobLevel</th>
#       <th class="col_heading level0 col10" >JobSatisfaction</th>
#       <th class="col_heading level0 col11" >MonthlyIncome</th>
#       <th class="col_heading level0 col12" >MonthlyRate</th>
#       <th class="col_heading level0 col13" >NumCompaniesWorked</th>
#       <th class="col_heading level0 col14" >PercentSalaryHike</th>
#       <th class="col_heading level0 col15" >PerformanceRating</th>
#       <th class="col_heading level0 col16" >RelationshipSatisfaction</th>
#       <th class="col_heading level0 col17" >StandardHours</th>
#       <th class="col_heading level0 col18" >StockOptionLevel</th>
#       <th class="col_heading level0 col19" >TotalWorkingYears</th>
#       <th class="col_heading level0 col20" >TrainingTimesLastYear</th>
#       <th class="col_heading level0 col21" >WorkLifeBalance</th>
#       <th class="col_heading level0 col22" >YearsAtCompany</th>
#       <th class="col_heading level0 col23" >YearsInCurrentRole</th>
#       <th class="col_heading level0 col24" >YearsSinceLastPromotion</th>
#       <th class="col_heading level0 col25" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5802d_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5802d_row0_col0" class="data row0 col0" >1470.000000</td>
#       <td id="T_5802d_row0_col1" class="data row0 col1" >1470.000000</td>
#       <td id="T_5802d_row0_col2" class="data row0 col2" >1470.000000</td>
#       <td id="T_5802d_row0_col3" class="data row0 col3" >1470.000000</td>
#       <td id="T_5802d_row0_col4" class="data row0 col4" >1470.000000</td>
#       <td id="T_5802d_row0_col5" class="data row0 col5" >1470.000000</td>

# %%
#Get a count of the numbers of employees that stayed and left the company.
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#Visualize the number of employees that stayed and left the company.
sns.countplot(df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#Shoe the number of employees that left and stayed by age.
plt.figure(figsize=(20,4))
sns.countplot(x='Age', hue='Attrition', data=df, palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
#Shoe the number of employees that left and stayed by age.
sns.countplot(x='Gender', hue='Attrition', data=df, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#Shoe the number of employees that left and stayed by age.
plt.figure(figsize=(23,4))
sns.countplot(x='JobRole', hue='Attrition', data=df, palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
#display histogram of all columns.
df.hist(figsize=(20,28), layout=(13,3), sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'DailyRate'}>,
#         <AxesSubplot:title={'center':'DistanceFromHome'}>],
#        [<AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'EmployeeCount'}>,
#         <AxesSubplot:title={'center':'EmployeeNumber'}>],
#        [<AxesSubplot:title={'center':'EnvironmentSatisfaction'}>,
#         <AxesSubplot:title={'center':'HourlyRate'}>,
#         <AxesSubplot:title={'center':'JobInvolvement'}>],
#        [<AxesSubplot:title={'center':'JobLevel'}>,
#         <AxesSubplot:title={'center':'JobSatisfaction'}>,
#         <AxesSubplot:title={'center':'MonthlyIncome'}>],
#        [<AxesSubplot:title={'center':'MonthlyRate'}>,
#         <AxesSubplot:title={'center':'NumCompaniesWorked'}>,
#         <AxesSubplot:title={'center':'PercentSalaryHike'}>],
#        [<AxesSubplot:title={'center':'PerformanceRating'}>,
#         <AxesSubplot:title={'center':'RelationshipSatisfaction'}>,
#         <AxesSubplot:title={'center':'StandardHours'}>],
#        [<AxesSubplot:title={'center':'StockOptionLevel'}>,
#         <AxesSubplot:title={'center':'TotalWorkingYears'}>,
#         <AxesSubplot:title={'center':'TrainingTimesLastYear'}>],
#        [<AxesSubplot:title={'center':'WorkLifeBalance'}>,
#         <AxesSubplot:title={'center':'YearsAtCompany'}>,
#         <AxesSubplot:title={'center':'YearsInCurrentRole'}>],
#        [<AxesSubplot:title={'center':'YearsSinceLastPromotion'}>,
#         <AxesSubplot:title={'center':'YearsWithCurrManager'}>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
#Print all of the data types and their unique values.
for column in df.columns:
    if df[column].dtype == object:
        print(str(column) + ' : ' + str(df[column].unique()))
        print(df[column].value_counts())
        print('____________________________________________')
# Out:
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ____________________________________________
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ____________________________________________
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ____________________________________________
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ____________________________________________
# Gender : ['Female' 'Male']
# Male      882
# Female    588
# Name: Gender, dtype: int64
# ____________________________________________
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# ____________________________________________
# MaritalStatus : ['Single' 'Married' 'Divorced']
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# ____________________________________________
# Over18 : ['Y']
# Y    1470
# Name: Over18, dtype: int64
# ____________________________________________
# OverTime : ['Yes' 'No']
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# ____________________________________________

# %%
#Remove some useless columns.
df.drop('Over18',axis=1,inplace=True)
df.drop('EmployeeNumber',axis=1,inplace=True)
df.drop('StandardHours',axis=1,inplace=True)
df.drop('EmployeeCount',axis=1,inplace=True)

# %%
#Get the correlation.
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# NumCompaniesWorked        0.299635   0.038153         -0.029251   0.126317
# PercentSalaryHike         0.003634   0.022704          0.040235  -0.011111
# PerformanceRating         0.001904   0.000473          0.027110  -0.024539
# RelationshipSatisfaction  0.053535   0.007846          0.006557  -0.009118
# StockOptionLevel          0.037510   0.042143          0.044872   0.018422
# TotalWorkingYears         0.680381   0.014515          0.004628   0.148280
# TrainingTimesLastYear    -0.019621   0.002453         -0.036942  -0.025100
# WorkLifeBalance          -0.021490  -0.037848         -0.026556   0.009819
# YearsAtCompany            0.311309  -0.034055          0.009508   0.069114
# YearsInCurrentRole        0.212901   0.009932          0.018845   0.060236
# YearsSinceLastPromotion   0.216513  -0.033229          0.010029   0.054254
# YearsWithCurrManager      0.202089  -0.026363          0.014406   0.069065
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.010146    0.024287        0.029820
# DailyRate                                0.018355    0.023381        0.046135
# DistanceFromHome                        -0.016075    0.031131        0.008783
# Education                               -0.027128    0.016775        0.042438
# EnvironmentSatisfaction                  1.000000   -0.049857       -0.008278
# HourlyRate                              -0.049857    1.000000        0.042861
# JobInvolvement                          -0.008278    0.042861        1.000000
# JobLevel                                 0.001212   -0.027853       -0.012630
# JobSatisfaction                         -0.006784   -0.071335       -0.021476
# MonthlyIncome                           -0.006259   -0.015794       -0.015271
# MonthlyRate                              0.037600   -0.015297       -0.016322
# NumCompaniesWorked                       0.012594    0.022157        0.015012
# PercentSalaryHike                       -0.031701   -0.009062       -0.017205
# PerformanceRating                       -0.029548   -0.002172       -0.029071
# RelationshipSatisfaction                 0.007665    0.001330        0.034297
# StockOptionLevel                         0.003432    0.050263        0.021523
# TotalWorkingYears                       -0.002693   -0.002334       -0.005533
# TrainingTimesLastYear                   -0.019359   -0.008548       -0.015338
# WorkLifeBalance                          0.027627   -0.004607       -0.014617
# YearsAtCompany                           0.001458   -0.019582       -0.021355
# YearsInCurrentRole                       0.018007   -0.024106        0.008717
# YearsSinceLastPromotion                  0.016194   -0.026716       -0.024184
# YearsWithCurrManager                    -0.004999   -0.020123        0.025976
#
#                           JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# Age                       0.509604        -0.004892       0.497855  ...
# DailyRate                 0.002966         0.030571       0.007707  ...
# DistanceFromHome          0.005303        -0.003669      -0.017014  ...
# Education                 0.101589        -0.011296       0.094961  ...
# EnvironmentSatisfaction   0.001212        -0.006784      -0.006259  ...
# HourlyRate               -0.027853        -0.071335      -0.015794  ...
# JobInvolvement           -0.012630        -0.021476      -0.015271  ...
# JobLevel                  1.000000        -0.001944       0.950300  ...
# JobSatisfaction          -0.001944         1.000000      -0.007157  ...
# MonthlyIncome             0.950300        -0.007157       1.000000  ...
# MonthlyRate               0.039563         0.000644       0.034814  ...
# NumCompaniesWorked        0.142501        -0.055699       0.149515  ...
# PercentSalaryHike        -0.034730         0.020002      -0.027269  ...
# PerformanceRating        -0.021222         0.002297      -0.017120  ...
# RelationshipSatisfaction  0.021642        -0.012454       0.025873  ...
# StockOptionLevel          0.013984         0.010690       0.005408  ...
# TotalWorkingYears         0.782208        -0.020185       0.772893  ...
# TrainingTimesLastYear    -0.018191        -0.005779      -0.021736  ...
# WorkLifeBalance           0.037818        -0.019459       0.030683  ...
# YearsAtCompany            0.534739        -0.003803       0.514285  ...
# YearsInCurrentRole        0.389447        -0.002305       0.363818  ...
# YearsSinceLastPromotion   0.353885        -0.018214       0.344978  ...
# YearsWithCurrManager      0.375281        -0.027656       0.344079  ...
#
#                           PerformanceRating  RelationshipSatisfaction  \
# Age                                0.001904                  0.053535
# DailyRate                          0.000473                  0.007846
# DistanceFromHome                   0.027110                  0.006557
# Education                         -0.024539                 -0.009118
# EnvironmentSatisfaction           -0.029548                  0.007665
# HourlyRate                        -0.002172                  0.001330
# JobInvolvement                    -0.029071                  0.034297
# JobLevel                          -0.021222                  0.021642
# JobSatisfaction                    0.002297                 -0.012454
# MonthlyIncome                     -0.017120                  0.025873
# MonthlyRate                       -0.009811                 -0.004085
# NumCompaniesWorked                -0.014095                  0.052733
# PercentSalaryHike                  0.773550                 -0.040490
# PerformanceRating                  1.000000                 -0.031351
# RelationshipSatisfaction          -0.031351                  1.000000
# StockOptionLevel                   0.003506                 -0.045952
# TotalWorkingYears                  0.006744                  0.024054
# TrainingTimesLastYear             -0.015579                  0.002497
# WorkLifeBalance                    0.002572                  0.019604
# YearsAtCompany                     0.003435                  0.019367
# YearsInCurrentRole                 0.034986                 -0.015123
# YearsSinceLastPromotion            0.017896                  0.033493
# YearsWithCurrManager               0.022827                 -0.000867
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.037510           0.680381
# DailyRate                         0.042143           0.014515
# DistanceFromHome                  0.044872           0.004628
# Education                         0.018422           0.148280
# EnvironmentSatisfaction           0.003432          -0.002693
# HourlyRate                        0.050263          -0.002334
# JobInvolvement                    0.021523          -0.005533
# JobLevel                          0.013984           0.782208
# JobSatisfaction                   0.010690          -0.020185
# MonthlyIncome                     0.005408           0.772893
# MonthlyRate                      -0.034323           0.026442
# NumCompaniesWorked                0.030075           0.237639
# PercentSalaryHike                 0.007528          -0.020608
# PerformanceRating                 0.003506           0.006744
# RelationshipSatisfaction         -0.045952           0.024054
# StockOptionLevel                  1.000000           0.010136
# TotalWorkingYears                 0.010136           1.000000
# TrainingTimesLastYear             0.011274          -0.035662
# WorkLifeBalance                   0.004129           0.001008
# YearsAtCompany                    0.015058           0.628133
# YearsInCurrentRole                0.050818           0.460365
# YearsSinceLastPromotion           0.014352           0.404858
# YearsWithCurrManager              0.024698           0.459188
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.019621        -0.021490
# DailyRate                              0.002453        -0.037848
# DistanceFromHome                      -0.036942        -0.026556
# Education                             -0.025100         0.009819
# EnvironmentSatisfaction               -0.019359         0.027627
# HourlyRate                            -0.008548        -0.004607
# JobInvolvement                        -0.015338        -0.014617
# JobLevel                              -0.018191         0.037818
# JobSatisfaction                       -0.005779        -0.019459
# MonthlyIncome                         -0.021736         0.030683
# MonthlyRate                            0.001467         0.007963
# NumCompaniesWorked                    -0.066054        -0.008366
# PercentSalaryHike                     -0.005221        -0.003280
# PerformanceRating                     -0.015579         0.002572
# RelationshipSatisfaction               0.002497         0.019604
# StockOptionLevel                       0.011274         0.004129
# TotalWorkingYears                     -0.035662         0.001008
# TrainingTimesLastYear                  1.000000         0.028072
# WorkLifeBalance                        0.028072         1.000000
# YearsAtCompany                         0.003569         0.012089
# YearsInCurrentRole                    -0.005738         0.049856
# YearsSinceLastPromotion               -0.002067         0.008941
# YearsWithCurrManager                  -0.004096         0.002759
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.311309            0.212901
# DailyRate                      -0.034055            0.009932
# DistanceFromHome                0.009508            0.018845
# Education                       0.069114            0.060236
# EnvironmentSatisfaction         0.001458            0.018007
# HourlyRate                     -0.019582           -0.024106
# JobInvolvement                 -0.021355            0.008717
# JobLevel                        0.534739            0.389447
# JobSatisfaction                -0.003803           -0.002305
# MonthlyIncome                   0.514285            0.363818
# MonthlyRate                    -0.023655           -0.012815
# NumCompaniesWorked             -0.118421           -0.090754
# PercentSalaryHike              -0.035991           -0.001520
# PerformanceRating               0.003435            0.034986
# RelationshipSatisfaction        0.019367           -0.015123
# StockOptionLevel                0.015058            0.050818
# TotalWorkingYears               0.628133            0.460365
# TrainingTimesLastYear           0.003569           -0.005738
# WorkLifeBalance                 0.012089            0.049856
# YearsAtCompany                  1.000000            0.758754
# YearsInCurrentRole              0.758754            1.000000
# YearsSinceLastPromotion         0.618409            0.548056
# YearsWithCurrManager            0.769212            0.714365
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.216513              0.202089
# DailyRate                               -0.033229             -0.026363
# DistanceFromHome                         0.010029              0.014406
# Education                                0.054254              0.069065
# EnvironmentSatisfaction                  0.016194             -0.004999
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobSatisfaction                         -0.018214             -0.027656
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# StockOptionLevel                         0.014352              0.024698
# TotalWorkingYears                        0.404858              0.459188
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCompany                           0.618409              0.769212
# YearsInCurrentRole                       0.548056              0.714365
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
#
# [23 rows x 23 columns]

# %%
#check correlation matrix with heatmap.
corr_mat = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr_mat, annot=True, fmt = '.0%',cmap = 'Blues')
plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# # Transform the data.

# %%
#Transform non-numerical into numerical column.
from sklearn.preprocessing import LabelEncoder

for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      23          1               2        624           2                 0
# 1      31          0               1        113           1                 7
# 2      19          1               2        805           1                 1
# 3      15          0               1        820           1                 2
# 4       9          0               2        312           1                 1
# ...   ...        ...             ...        ...         ...               ...
# 1465   18          0               1        494           1                22
# 1466   21          0               2        327           1                 5
# 1467    9          0               2         39           1                 3
# 1468   31          0               1        579           2                 1
# 1469   16          0               2        336           1                 7
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0             1               1                        1       0  ...
# 1             0               1                        2       1  ...
# 2             1               4                        3       1  ...
# 3             3               1                        3       0  ...
# 4             0               3                        0       1  ...
# ...         ...             ...                      ...     ...  ...
# 1465          1               3                        2       1  ...
# 1466          0               3                        3       1  ...
# 1467          2               1                        1       1  ...
# 1468          2               3                        3       1  ...
# 1469          2               3                        1       1  ...
#
#       PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                     0                         0                 0
# 1                     1                         3                 1
# 2                     0                         1                 0
# 3                     0                         2                 0
# 4                     0                         3                 1
# ...                 ...                       ...               ...
# 1465                  0                         2                 1
# 1466                  0                         0                 1
# 1467                  1                         1                 1
# 1468                  0                         3                 0
# 1469                  0                         0                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                0
# 1                    10                      3                2
# 2                     7                      3                2
# 3                     8                      3                2
# 4                     6                      3                2
# ...                 ...                    ...              ...
# 1465                 17                      3                2
# 1466                  9                      5                2
# 1467                  6                      0                2
# 1468                 17                      3                1
# 1469                  6                      3                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 31 columns]

# %%
#Create a new column.
df['Age_Years'] = df['Age']

# %%
#Drop the age column.
df.drop('Age', axis=1, inplace=True)

# %%
#Show the dataframe.
df
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             1               2        624           2                 0
# 1             0               1        113           1                 7
# 2             1               2        805           1                 1
# 3             0               1        820           1                 2
# 4             0               2        312           1                 1
# ...         ...             ...        ...         ...               ...
# 1465          0               1        494           1                22
# 1466          0               2        327           1                 5
# 1467          0               2         39           1                 3
# 1468          0               1        579           2                 1
# 1469          0               2        336           1                 7
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0             1               1                        1       0          64
# 1             0               1                        2       1          31
# 2             1               4                        3       1          62
# 3             3               1                        3       0          26
# 4             0               3                        0       1          10
# ...         ...             ...                      ...     ...         ...
# 1465          1               3                        2       1          11
# 1466          0               3                        3       1          12
# 1467          2               1                        1       1          57
# 1468          2               3                        3       1          33
# 1469          2               3                        1       1          52
#
#       ...  RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0     ...                         0                 0                  8
# 1     ...                         3                 1                 10
# 2     ...                         1                 0                  7
# 3     ...                         2                 0                  8
# 4     ...                         3                 1                  6
# ...   ...                       ...               ...                ...
# 1465  ...                         2                 1                 17
# 1466  ...                         0                 1                  9
# 1467  ...                         1                 1                  6
# 1468  ...                         3                 0                 17
# 1469  ...                         0                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         0                0               6
# 1                         3                2              10
# 2                         3                2               0
# 3                         3                2               8
# 4                         3                2               2
# ...                     ...              ...             ...
# 1465                      3                2               5
# 1466                      5                2               7
# 1467                      0                2               6
# 1468                      3                1               9
# 1469                      3                3               4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
#       Age_Years
# 0            23
# 1            31
# 2            19
# 3            15
# 4             9
# ...         ...
# 1465         18
# 1466         21
# 1467          9
# 1468         31
# 1469         16
#
# [1470 rows x 31 columns]

# %%
# Let's check the data distribution among all the columns.
df.plot(kind='density', subplots=True, layout=(12,3), sharex=False, legend=True, fontsize=1, figsize=(20,18))
plt.show()

# %% [markdown]
# # Remove skewness and outliers

# %%
#checking outliers with boxplot.
df.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,11:22].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,22:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#Lets quantify.
from scipy.stats import zscore
(np.abs(zscore(df))<3).all()
# Out:
# Attrition                    True
# BusinessTravel               True
# DailyRate                    True
# Department                   True
# DistanceFromHome             True
# Education                    True
# EducationField               True
# EnvironmentSatisfaction      True
# Gender                       True
# HourlyRate                   True
# JobInvolvement               True
# JobLevel                     True
# JobRole                      True
# JobSatisfaction              True
# MaritalStatus                True
# MonthlyIncome                True
# MonthlyRate                  True
# NumCompaniesWorked           True
# OverTime                     True
# PercentSalaryHike            True
# PerformanceRating            True
# RelationshipSatisfaction     True
# StockOptionLevel             True
# TotalWorkingYears           False
# TrainingTimesLastYear        True
# WorkLifeBalance              True
# YearsAtCompany              False
# YearsInCurrentRole          False
# YearsSinceLastPromotion     False
# YearsWithCurrManager        False
# Age_Years                    True
# dtype: bool

# %%
#display zscore for removing outliers.
from scipy.stats import zscore
z = np.abs(zscore(df))
z
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      2.280906        0.590048   0.713914    1.401512          1.010909
# 1      0.438422        0.913194   1.302446    0.493817          0.147150
# 2      2.280906        0.590048   1.428124    0.493817          0.887515
# 3      0.438422        0.913194   1.487313    0.493817          0.764121
# 4      0.438422        0.590048   0.517210    0.493817          0.887515
# ...         ...             ...        ...         ...               ...
# 1465   0.438422        0.913194   0.200946    0.493817          1.703764
# 1466   0.438422        0.590048   0.458021    0.493817          0.393938
# 1467   0.438422        0.590048   1.594443    0.493817          0.640727
# 1468   0.438422        0.913194   0.536349    1.401512          0.887515
# 1469   0.438422        0.590048   0.422508    0.493817          0.147150
#
#       Education  EducationField  EnvironmentSatisfaction    Gender  \
# 0      0.891688        0.937414                 0.660531  1.224745
# 1      1.868426        0.937414                 0.254625  0.816497
# 2      0.891688        1.316673                 1.169781  0.816497
# 3      1.061787        0.937414                 1.169781  1.224745
# 4      1.868426        0.565311                 1.575686  0.816497
# ...         ...             ...                      ...       ...
# 1465   0.891688        0.565311                 0.254625  0.816497
# 1466   1.868426        0.565311                 1.169781  0.816497
# 1467   0.085049        0.937414                 0.660531  0.816497
# 1468   0.085049        0.565311                 1.169781  0.816497
# 1469   0.085049        0.565311                 0.660531  0.816497
#
#       HourlyRate  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0       1.383138  ...                  1.584178          0.932014
# 1       0.240677  ...                  1.191438          0.241988
# 2       1.284725  ...                  0.658973          0.932014
# 3       0.486709  ...                  0.266233          0.932014
# 4       1.274014  ...                  1.191438          0.241988
# ...          ...  ...                       ...               ...
# 1465    1.224807  ...                  0.266233          0.241988
# 1466    1.175601  ...                  1.584178          0.241988
# 1467    1.038693  ...                  0.658973          0.241988
# 1468    0.142264  ...                  1.191438          0.932014
# 1469    0.792660  ...                  1.584178          0.932014
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0              0.421735               2.171982         2.493820
# 1              0.164441               0.155707         0.338096
# 2              0.550382               0.155707         0.338096
# 3              0.421735               0.155707         0.338096
# 4              0.679030               0.155707         0.338096
# ...                 ...                    ...              ...
# 1465           0.736090               0.155707         0.338096
# 1466           0.293088               1.707500         0.338096
# 1467           0.679030               2.171982         0.338096
# 1468           0.736090               0.155707         1.077862
# 1469           0.679030               0.155707         1.754054
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0           0.163801            0.063296                 0.679146
# 1           0.497250            0.764998                 0.368715
# 2           1.155378            1.167687                 0.679146
# 3           0.166724            0.764998                 0.252146
# 4           0.824853            0.615492                 0.058285
# ...              ...                 ...                      ...
# 1465        0.329064            0.615492                 0.679146
# 1466        0.001462            0.764998                 0.368715
# 1467        0.163801            0.615492                 0.679146
# 1468        0.331987            0.488900                 0.679146
# 1469        0.494327            0.339394                 0.368715
#
#       YearsWithCurrManager  Age_Years
# 0                 0.245834   0.446350
# 1                 0.806541   1.322365
# 2                 1.155935   0.008343
# 3                 1.155935   0.429664
# 4                 0.595227   1.086676
# ...                    ...        ...
# 1465              0.314873   0.101159
# 1466              0.806541   0.227347
# 1467              0.314873   1.086676
# 1468              1.086895   1.322365
# 1469              0.595227   0.320163
#
# [1470 rows x 31 columns]

# %%
#threshold for zscore values ----> above 3 are considerd outliers.
threshold = 3 
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([29, 28, 26, 28, 27, 28, 23, 23, 26, 28, 27, 28, 29, 23, 26, 28, 29,
#        28, 23, 29, 26, 27, 28, 27, 29, 26, 28, 23, 26, 27, 28, 28, 29, 23,
#        26, 26, 28, 28, 23, 27, 26, 26, 28, 26, 29, 28, 26, 23, 26, 28, 29,
#        23, 29, 26, 28, 26, 29, 28, 27, 27, 26, 28, 28, 28, 26, 28, 28, 29,
#        23, 26, 28, 26, 28, 28, 29, 28, 23, 26, 27, 28, 28, 27, 23, 28, 29,
#        26, 28, 28, 26, 23, 26, 26, 26, 28, 28, 23, 28, 28, 28, 28, 23, 28,
#        28, 27, 28, 29, 27, 23, 28, 27], dtype=int64))

# %%
#removing outliers.
new_df = df[(z<3).all(axis=1)]
print(df.shape)
print(new_df.shape)

df = new_df
print(df.shape)
# Out:
# (1470, 31)
# (1387, 31)
# (1387, 31)

# %%
#checking skewness
df.skew().sort_values(ascending=False)
# Out:
# PerformanceRating           1.931566
# Attrition                   1.805983
# YearsSinceLastPromotion     1.756335
# YearsAtCompany              1.248623
# JobLevel                    1.126075
# NumCompaniesWorked          1.037715
# TotalWorkingYears           1.034487
# StockOptionLevel            0.962332
# DistanceFromHome            0.954752
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# YearsInCurrentRole          0.726675
# YearsWithCurrManager        0.694506
# TrainingTimesLastYear       0.577614
# EducationField              0.544868
# Age_Years                   0.472280
# Department                  0.183919
# MonthlyIncome               0.112326
# MonthlyRate                 0.024344
# DailyRate                  -0.012403
# HourlyRate                 -0.030481
# MaritalStatus              -0.160952
# Education                  -0.289024
# RelationshipSatisfaction   -0.295686
# EnvironmentSatisfaction    -0.325285
# JobSatisfaction            -0.345612
# JobRole                    -0.386843
# Gender                     -0.417296
# JobInvolvement             -0.501401
# WorkLifeBalance            -0.557100
# BusinessTravel             -1.426774
# dtype: float64

# %% [markdown]
# # Data Preprocessing

# %%
#Splitting the independent and target variable in x and y.
x = df.drop("Attrition",axis=1)
y = df['Attrition']

# %%
print(x.shape)
print(y.shape)
# Out:
# (1387, 30)
# (1387,)

# %%
x
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                  2        624           2                 0          1
# 1                  1        113           1                 7          0
# 2                  2        805           1                 1          1
# 3                  1        820           1                 2          3
# 4                  2        312           1                 1          0
# ...              ...        ...         ...               ...        ...
# 1465               1        494           1                22          1
# 1466               2        327           1                 5          0
# 1467               2         39           1                 3          2
# 1468               1        579           2                 1          2
# 1469               2        336           1                 7          2
#
#       EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0                  1                        1       0          64
# 1                  1                        2       1          31
# 2                  4                        3       1          62
# 3                  1                        3       0          26
# 4                  3                        0       1          10
# ...              ...                      ...     ...         ...
# 1465               3                        2       1          11
# 1466               3                        3       1          12
# 1467               1                        1       1          57
# 1468               3                        3       1          33
# 1469               3                        1       1          52
#
#       JobInvolvement  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0                  2  ...                         0                 0
# 1                  1  ...                         3                 1
# 2                  1  ...                         1                 0
# 3                  2  ...                         2                 0
# 4                  2  ...                         3                 1
# ...              ...  ...                       ...               ...
# 1465               3  ...                         2                 1
# 1466               1  ...                         0                 1
# 1467               3  ...                         1                 1
# 1468               1  ...                         3                 0
# 1469               3  ...                         0                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                0
# 1                    10                      3                2
# 2                     7                      3                2
# 3                     8                      3                2
# 4                     6                      3                2
# ...                 ...                    ...              ...
# 1465                 17                      3                2
# 1466                  9                      5                2
# 1467                  6                      0                2
# 1468                 17                      3                1
# 1469                  6                      3                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager  Age_Years
# 0                        5         23
# 1                        7         31
# 2                        0         19
# 3                        0         15
# 4                        2          9
# ...                    ...        ...
# 1465                     3         18
# 1466                     7         21
# 1467                     3          9
# 1468                     8         31
# 1469                     2         16
#
# [1387 rows x 30 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int32

# %% [markdown]
# # Scaling with StandardScaler.

# %%
from sklearn.preprocessing import StandardScaler

st = StandardScaler()
x = st.fit_transform(x)
x
# Out:
# array([[ 0.59312579,  0.70565289,  1.40537338, ..., -0.71069889,
#          0.36826963,  0.5366811 ],
#        [-0.90535412, -1.31239331, -0.49633675, ..., -0.31047991,
#          0.9821999 ,  1.44211114],
#        [ 0.59312579,  1.42045986, -0.49633675, ..., -0.71069889,
#         -1.16655603,  0.08396607],
#        ...,
#        [ 0.59312579, -1.60463484, -0.49633675, ..., -0.71069889,
#         -0.24566063, -1.04782149],
#        [-0.90535412,  0.52793845,  1.40537338, ..., -0.71069889,
#          1.28916503,  1.44211114],
#        [ 0.59312579, -0.43171953, -0.49633675, ..., -0.31047991,
#         -0.55262577, -0.2555702 ]])

# %% [markdown]
# # Since the outcome has only two variables we will use binary classification model.

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

from sklearn.svm import SVC
svc = SVC()

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score

# %% [markdown]
# # Training process begins

# %% [markdown]
# Finding best random_state

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    pred_test = lr.predict(x_test)
    acc = accuracy_score(y_test, pred_test)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.8669064748201439 random_state 1
# accuracy 0.8776978417266187 random_state 2
# accuracy 0.8848920863309353 random_state 3
# accuracy 0.8381294964028777 random_state 4
# accuracy 0.8381294964028777 random_state 5
# accuracy 0.9100719424460432 random_state 6
# accuracy 0.8705035971223022 random_state 7
# accuracy 0.8597122302158273 random_state 8
# accuracy 0.8741007194244604 random_state 9
# accuracy 0.8453237410071942 random_state 10
# accuracy 0.8848920863309353 random_state 11
# accuracy 0.8597122302158273 random_state 12
# accuracy 0.8884892086330936 random_state 13
# accuracy 0.8489208633093526 random_state 14
# accuracy 0.8525179856115108 random_state 15
# accuracy 0.8489208633093526 random_state 16
# accuracy 0.8705035971223022 random_state 17
# accuracy 0.8597122302158273 random_state 18
# accuracy 0.8776978417266187 random_state 19
# accuracy 0.8633093525179856 random_state 20
# accuracy 0.8453237410071942 random_state 21
# accuracy 0.8669064748201439 random_state 22
# accuracy 0.8561151079136691 random_state 23
# accuracy 0.8597122302158273 random_state 24
# accuracy 0.8884892086330936 random_state 25
# accuracy 0.8669064748201439 random_state 26
# accuracy 0.841726618705036 random_state 27
# accuracy 0.8309352517985612 random_state 28
# accuracy 0.8597122302158273 random_state 29
# accuracy 0.8812949640287769 random_state 30
# accuracy 0.8669064748201439 random_state 31
# accuracy 0.8812949640287769 random_state 32
# accuracy 0.8633093525179856 random_state 33
# accuracy 0.8561151079136691 random_state 34
# accuracy 0.8561151079136691 random_state 35
# accuracy 0.8741007194244604 random_state 36
# accuracy 0.8597122302158273 random_state 37
# accuracy 0.8525179856115108 random_state 38
# accuracy 0.8669064748201439 random_state 39
# accuracy 0.8525179856115108 random_state 40
# accuracy 0.8525179856115108 random_state 41
# accuracy 0.841726618705036 random_state 42
# accuracy 0.8705035971223022 random_state 43
# accuracy 0.8597122302158273 random_state 44
# accuracy 0.9100719424460432 random_state 45
# accuracy 0.8597122302158273 random_state 46
# accuracy 0.8812949640287769 random_state 47
# accuracy 0.8884892086330936 random_state 48
# accuracy 0.8597122302158273 random_state 49
# accuracy 0.8705035971223022 random_state 50
# accuracy 0.8705035971223022 random_state 51
# accuracy 0.8309352517985612 random_state 52
# accuracy 0.8597122302158273 random_state 53
# accuracy 0.8812949640287769 random_state 54
# accuracy 0.9100719424460432 random_state 55
# accuracy 0.8884892086330936 random_state 56
# accuracy 0.8848920863309353 random_state 57
# accuracy 0.8776978417266187 random_state 58
# accuracy 0.8525179856115108 random_state 59
# accuracy 0.8309352517985612 random_state 60
# accuracy 0.8525179856115108 random_state 61
# accuracy 0.8741007194244604 random_state 62
# accuracy 0.8705035971223022 random_state 63
# accuracy 0.8669064748201439 random_state 64
# accuracy 0.841726618705036 random_state 65
# accuracy 0.8669064748201439 random_state 66
# accuracy 0.8884892086330936 random_state 67
# accuracy 0.8633093525179856 random_state 68
# accuracy 0.8884892086330936 random_state 69
# accuracy 0.8633093525179856 random_state 70
# accuracy 0.89568345323741 random_state 71
# accuracy 0.8848920863309353 random_state 72
# accuracy 0.8992805755395683 random_state 73
# accuracy 0.8597122302158273 random_state 74
# accuracy 0.8669064748201439 random_state 75
# accuracy 0.89568345323741 random_state 76
# accuracy 0.8848920863309353 random_state 77
# accuracy 0.8741007194244604 random_state 78
# accuracy 0.8669064748201439 random_state 79
# accuracy 0.8741007194244604 random_state 80
# accuracy 0.8705035971223022 random_state 81
# accuracy 0.8489208633093526 random_state 82
# accuracy 0.8812949640287769 random_state 83
# accuracy 0.8669064748201439 random_state 84
# accuracy 0.8776978417266187 random_state 85
# accuracy 0.8705035971223022 random_state 86
# accuracy 0.8741007194244604 random_state 87
# accuracy 0.8633093525179856 random_state 88
# accuracy 0.8561151079136691 random_state 89
# accuracy 0.8776978417266187 random_state 90
# accuracy 0.8741007194244604 random_state 91
# accuracy 0.89568345323741 random_state 92
# accuracy 0.8705035971223022 random_state 93
# accuracy 0.8597122302158273 random_state 94
# accuracy 0.8705035971223022 random_state 95
# accuracy 0.8561151079136691 random_state 96
# accuracy 0.8597122302158273 random_state 97
# accuracy 0.8561151079136691 random_state 98
# accuracy 0.8848920863309353 random_state 99
# accuracy 0.8705035971223022 random_state 100
# accuracy 0.8776978417266187 random_state 101
# accuracy 0.8561151079136691 random_state 102
# accuracy 0.8669064748201439 random_state 103
# accuracy 0.841726618705036 random_state 104
# accuracy 0.8525179856115108 random_state 105
# accuracy 0.9028776978417267 random_state 106
# accuracy 0.8776978417266187 random_state 107
# accuracy 0.8309352517985612 random_state 108
# accuracy 0.9100719424460432 random_state 109
# accuracy 0.8776978417266187 random_state 110
# accuracy 0.8705035971223022 random_state 111
# accuracy 0.8525179856115108 random_state 112
# accuracy 0.8561151079136691 random_state 113
# accuracy 0.8920863309352518 random_state 114
# accuracy 0.8776978417266187 random_state 115
# accuracy 0.8848920863309353 random_state 116
# accuracy 0.8848920863309353 random_state 117
# accuracy 0.8776978417266187 random_state 118
# accuracy 0.8597122302158273 random_state 119
# accuracy 0.8812949640287769 random_state 120
# accuracy 0.8812949640287769 random_state 121
# accuracy 0.8741007194244604 random_state 122
# accuracy 0.8812949640287769 random_state 123
# accuracy 0.8597122302158273 random_state 124
# accuracy 0.8381294964028777 random_state 125
# accuracy 0.9064748201438849 random_state 126
# accuracy 0.8561151079136691 random_state 127
# accuracy 0.8309352517985612 random_state 128
# accuracy 0.8705035971223022 random_state 129
# accuracy 0.8705035971223022 random_state 130
# accuracy 0.8489208633093526 random_state 131
# accuracy 0.8489208633093526 random_state 132
# accuracy 0.8776978417266187 random_state 133
# accuracy 0.8812949640287769 random_state 134
# accuracy 0.8920863309352518 random_state 135
# accuracy 0.8669064748201439 random_state 136
# accuracy 0.8381294964028777 random_state 137
# accuracy 0.8381294964028777 random_state 138
# accuracy 0.8848920863309353 random_state 139
# accuracy 0.841726618705036 random_state 140
# accuracy 0.8705035971223022 random_state 141
# accuracy 0.8129496402877698 random_state 142
# accuracy 0.8597122302158273 random_state 143
# accuracy 0.8633093525179856 random_state 144
# accuracy 0.8669064748201439 random_state 145
# accuracy 0.8633093525179856 random_state 146
# accuracy 0.8453237410071942 random_state 147
# accuracy 0.8741007194244604 random_state 148
# accuracy 0.8705035971223022 random_state 149
# accuracy 0.9028776978417267 random_state 150
# accuracy 0.8237410071942446 random_state 151
# accuracy 0.8633093525179856 random_state 152
# accuracy 0.8669064748201439 random_state 153
# accuracy 0.9064748201438849 random_state 154
# accuracy 0.8741007194244604 random_state 155
# accuracy 0.8525179856115108 random_state 156
# accuracy 0.8633093525179856 random_state 157
# accuracy 0.8848920863309353 random_state 158
# accuracy 0.8597122302158273 random_state 159
# accuracy 0.8669064748201439 random_state 160
# accuracy 0.8669064748201439 random_state 161
# accuracy 0.7949640287769785 random_state 162
# accuracy 0.8812949640287769 random_state 163
# accuracy 0.8776978417266187 random_state 164
# accuracy 0.8812949640287769 random_state 165
# accuracy 0.8848920863309353 random_state 166
# accuracy 0.8453237410071942 random_state 167
# accuracy 0.8669064748201439 random_state 168
# accuracy 0.8633093525179856 random_state 169
# accuracy 0.8920863309352518 random_state 170
# accuracy 0.8669064748201439 random_state 171
# accuracy 0.8776978417266187 random_state 172
# accuracy 0.8705035971223022 random_state 173
# accuracy 0.8453237410071942 random_state 174
# accuracy 0.8884892086330936 random_state 175
# accuracy 0.89568345323741 random_state 176
# accuracy 0.8741007194244604 random_state 177
# accuracy 0.8812949640287769 random_state 178
# accuracy 0.8633093525179856 random_state 179
# accuracy 0.89568345323741 random_state 180
# accuracy 0.8812949640287769 random_state 181
# accuracy 0.8669064748201439 random_state 182
# accuracy 0.8273381294964028 random_state 183
# accuracy 0.8776978417266187 random_state 184
# accuracy 0.8597122302158273 random_state 185
# accuracy 0.8992805755395683 random_state 186
# accuracy 0.8561151079136691 random_state 187
# accuracy 0.8992805755395683 random_state 188
# accuracy 0.8597122302158273 random_state 189
# accuracy 0.8561151079136691 random_state 190
# accuracy 0.8741007194244604 random_state 191
# accuracy 0.8776978417266187 random_state 192
# accuracy 0.8669064748201439 random_state 193
# accuracy 0.8669064748201439 random_state 194
# accuracy 0.8776978417266187 random_state 195
# accuracy 0.8741007194244604 random_state 196
# accuracy 0.8489208633093526 random_state 197
# accuracy 0.8489208633093526 random_state 198
# accuracy 0.8741007194244604 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.9100719424460432 On Random_state  6

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    rfc = RandomForestClassifier()
    rfc.fit(x_train,y_train)
    pred_test = rfc.predict(x_test)
    acc = accuracy_score(y_test, pred_test)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.841726618705036 random_state 1
# accuracy 0.8741007194244604 random_state 2
# accuracy 0.8776978417266187 random_state 3
# accuracy 0.8669064748201439 random_state 4
# accuracy 0.8345323741007195 random_state 5
# accuracy 0.8920863309352518 random_state 6
# accuracy 0.8489208633093526 random_state 7
# accuracy 0.8633093525179856 random_state 8
# accuracy 0.8489208633093526 random_state 9
# accuracy 0.8345323741007195 random_state 10
# accuracy 0.8669064748201439 random_state 11
# accuracy 0.8201438848920863 random_state 12
# accuracy 0.8561151079136691 random_state 13
# accuracy 0.8201438848920863 random_state 14
# accuracy 0.8489208633093526 random_state 15
# accuracy 0.8381294964028777 random_state 16
# accuracy 0.8489208633093526 random_state 17
# accuracy 0.8381294964028777 random_state 18
# accuracy 0.8489208633093526 random_state 19
# accuracy 0.8561151079136691 random_state 20
# accuracy 0.8345323741007195 random_state 21
# accuracy 0.8381294964028777 random_state 22
# accuracy 0.841726618705036 random_state 23
# accuracy 0.8381294964028777 random_state 24
# accuracy 0.8812949640287769 random_state 25
# accuracy 0.841726618705036 random_state 26
# accuracy 0.8309352517985612 random_state 27
# accuracy 0.8309352517985612 random_state 28
# accuracy 0.8489208633093526 random_state 29
# accuracy 0.8812949640287769 random_state 30
# accuracy 0.8489208633093526 random_state 31
# accuracy 0.8812949640287769 random_state 32
# accuracy 0.8561151079136691 random_state 33
# accuracy 0.8345323741007195 random_state 34
# accuracy 0.8453237410071942 random_state 35
# accuracy 0.8381294964028777 random_state 36
# accuracy 0.8381294964028777 random_state 37
# accuracy 0.8273381294964028 random_state 38
# accuracy 0.8525179856115108 random_state 39
# accuracy 0.8165467625899281 random_state 40
# accuracy 0.8453237410071942 random_state 41
# accuracy 0.8381294964028777 random_state 42
# accuracy 0.8561151079136691 random_state 43
# accuracy 0.8669064748201439 random_state 44
# accuracy 0.8812949640287769 random_state 45
# accuracy 0.8381294964028777 random_state 46
# accuracy 0.8453237410071942 random_state 47
# accuracy 0.8848920863309353 random_state 48
# accuracy 0.8525179856115108 random_state 49
# accuracy 0.8561151079136691 random_state 50
# accuracy 0.8776978417266187 random_state 51
# accuracy 0.841726618705036 random_state 52
# accuracy 0.8201438848920863 random_state 53
# accuracy 0.841726618705036 random_state 54
# accuracy 0.8705035971223022 random_state 55
# accuracy 0.8884892086330936 random_state 56
# accuracy 0.8669064748201439 random_state 57
# accuracy 0.8669064748201439 random_state 58
# accuracy 0.8165467625899281 random_state 59
# accuracy 0.8381294964028777 random_state 60
# accuracy 0.8381294964028777 random_state 61
# accuracy 0.8561151079136691 random_state 62
# accuracy 0.8776978417266187 random_state 63
# accuracy 0.8489208633093526 random_state 64
# accuracy 0.8237410071942446 random_state 65
# accuracy 0.8561151079136691 random_state 66
# accuracy 0.8633093525179856 random_state 67
# accuracy 0.8597122302158273 random_state 68
# accuracy 0.8812949640287769 random_state 69
# accuracy 0.8633093525179856 random_state 70
# accuracy 0.8561151079136691 random_state 71
# accuracy 0.8812949640287769 random_state 72
# accuracy 0.8597122302158273 random_state 73
# accuracy 0.8345323741007195 random_state 74
# accuracy 0.8381294964028777 random_state 75
# accuracy 0.8884892086330936 random_state 76
# accuracy 0.8669064748201439 random_state 77
# accuracy 0.8525179856115108 random_state 78
# accuracy 0.8381294964028777 random_state 79
# accuracy 0.8705035971223022 random_state 80
# accuracy 0.8741007194244604 random_state 81
# accuracy 0.8669064748201439 random_state 82
# accuracy 0.8489208633093526 random_state 83
# accuracy 0.8381294964028777 random_state 84
# accuracy 0.8597122302158273 random_state 85
# accuracy 0.8525179856115108 random_state 86
# accuracy 0.8453237410071942 random_state 87
# accuracy 0.8165467625899281 random_state 88
# accuracy 0.8561151079136691 random_state 89
# accuracy 0.8705035971223022 random_state 90
# accuracy 0.8812949640287769 random_state 91
# accuracy 0.8741007194244604 random_state 92
# accuracy 0.8597122302158273 random_state 93
# accuracy 0.8381294964028777 random_state 94
# accuracy 0.8453237410071942 random_state 95
# accuracy 0.8273381294964028 random_state 96
# accuracy 0.8273381294964028 random_state 97
# accuracy 0.8381294964028777 random_state 98
# accuracy 0.8741007194244604 random_state 99
# accuracy 0.8345323741007195 random_state 100
# accuracy 0.8453237410071942 random_state 101
# accuracy 0.8165467625899281 random_state 102
# accuracy 0.8273381294964028 random_state 103
# accuracy 0.8237410071942446 random_state 104
# accuracy 0.8237410071942446 random_state 105
# accuracy 0.89568345323741 random_state 106
# accuracy 0.8705035971223022 random_state 107
# accuracy 0.8129496402877698 random_state 108
# accuracy 0.8848920863309353 random_state 109
# accuracy 0.8237410071942446 random_state 110
# accuracy 0.8705035971223022 random_state 111
# accuracy 0.8525179856115108 random_state 112
# accuracy 0.8345323741007195 random_state 113
# accuracy 0.8884892086330936 random_state 114
# accuracy 0.8776978417266187 random_state 115
# accuracy 0.8453237410071942 random_state 116
# accuracy 0.8884892086330936 random_state 117
# accuracy 0.8345323741007195 random_state 118
# accuracy 0.8848920863309353 random_state 119
# accuracy 0.8489208633093526 random_state 120
# accuracy 0.8597122302158273 random_state 121
# accuracy 0.8273381294964028 random_state 122
# accuracy 0.8705035971223022 random_state 123
# accuracy 0.8489208633093526 random_state 124
# accuracy 0.8561151079136691 random_state 125
# accuracy 0.9028776978417267 random_state 126
# accuracy 0.8633093525179856 random_state 127
# accuracy 0.8129496402877698 random_state 128
# accuracy 0.8381294964028777 random_state 129
# accuracy 0.8381294964028777 random_state 130
# accuracy 0.8057553956834532 random_state 131
# accuracy 0.8309352517985612 random_state 132
# accuracy 0.841726618705036 random_state 133
# accuracy 0.8561151079136691 random_state 134
# accuracy 0.8776978417266187 random_state 135
# accuracy 0.8597122302158273 random_state 136
# accuracy 0.8237410071942446 random_state 137
# accuracy 0.8345323741007195 random_state 138
# accuracy 0.8633093525179856 random_state 139
# accuracy 0.8381294964028777 random_state 140
# accuracy 0.8381294964028777 random_state 141
# accuracy 0.8057553956834532 random_state 142
# accuracy 0.8561151079136691 random_state 143
# accuracy 0.841726618705036 random_state 144
# accuracy 0.841726618705036 random_state 145
# accuracy 0.8561151079136691 random_state 146
# accuracy 0.8633093525179856 random_state 147
# accuracy 0.8489208633093526 random_state 148
# accuracy 0.8489208633093526 random_state 149
# accuracy 0.8525179856115108 random_state 150
# accuracy 0.8489208633093526 random_state 151
# accuracy 0.8705035971223022 random_state 152
# accuracy 0.8633093525179856 random_state 153
# accuracy 0.8705035971223022 random_state 154
# accuracy 0.8597122302158273 random_state 155
# accuracy 0.8381294964028777 random_state 156
# accuracy 0.8381294964028777 random_state 157
# accuracy 0.8669064748201439 random_state 158
# accuracy 0.8561151079136691 random_state 159
# accuracy 0.8525179856115108 random_state 160
# accuracy 0.8453237410071942 random_state 161
# accuracy 0.8201438848920863 random_state 162
# accuracy 0.8669064748201439 random_state 163
# accuracy 0.89568345323741 random_state 164
# accuracy 0.8273381294964028 random_state 165
# accuracy 0.8812949640287769 random_state 166
# accuracy 0.8093525179856115 random_state 167
# accuracy 0.8597122302158273 random_state 168
# accuracy 0.841726618705036 random_state 169
# accuracy 0.8884892086330936 random_state 170
# accuracy 0.8381294964028777 random_state 171
# accuracy 0.8669064748201439 random_state 172
# accuracy 0.8237410071942446 random_state 173
# accuracy 0.8093525179856115 random_state 174
# accuracy 0.8669064748201439 random_state 175
# accuracy 0.8884892086330936 random_state 176
# accuracy 0.8669064748201439 random_state 177
# accuracy 0.8561151079136691 random_state 178
# accuracy 0.8597122302158273 random_state 179
# accuracy 0.9028776978417267 random_state 180
# accuracy 0.8741007194244604 random_state 181
# accuracy 0.8597122302158273 random_state 182
# accuracy 0.8273381294964028 random_state 183
# accuracy 0.8561151079136691 random_state 184
# accuracy 0.8525179856115108 random_state 185
# accuracy 0.8381294964028777 random_state 186
# accuracy 0.8597122302158273 random_state 187
# accuracy 0.8525179856115108 random_state 188
# accuracy 0.8633093525179856 random_state 189
# accuracy 0.841726618705036 random_state 190
# accuracy 0.8489208633093526 random_state 191
# accuracy 0.8489208633093526 random_state 192
# accuracy 0.8561151079136691 random_state 193
# accuracy 0.8561151079136691 random_state 194
# accuracy 0.8812949640287769 random_state 195
# accuracy 0.841726618705036 random_state 196
# accuracy 0.8345323741007195 random_state 197
# accuracy 0.8381294964028777 random_state 198
# accuracy 0.8741007194244604 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.9028776978417267 On Random_state  126

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    dtc = DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred_test = dtc.predict(x_test)
    acc = accuracy_score(y_test, pred_test)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.7913669064748201 random_state 1
# accuracy 0.7841726618705036 random_state 2
# accuracy 0.737410071942446 random_state 3
# accuracy 0.7769784172661871 random_state 4
# accuracy 0.7733812949640287 random_state 5
# accuracy 0.7985611510791367 random_state 6
# accuracy 0.7338129496402878 random_state 7
# accuracy 0.7769784172661871 random_state 8
# accuracy 0.7697841726618705 random_state 9
# accuracy 0.7194244604316546 random_state 10
# accuracy 0.7697841726618705 random_state 11
# accuracy 0.7985611510791367 random_state 12
# accuracy 0.7985611510791367 random_state 13
# accuracy 0.7589928057553957 random_state 14
# accuracy 0.8129496402877698 random_state 15
# accuracy 0.737410071942446 random_state 16
# accuracy 0.7733812949640287 random_state 17
# accuracy 0.7913669064748201 random_state 18
# accuracy 0.7697841726618705 random_state 19
# accuracy 0.7841726618705036 random_state 20
# accuracy 0.8129496402877698 random_state 21
# accuracy 0.7733812949640287 random_state 22
# accuracy 0.7877697841726619 random_state 23
# accuracy 0.7338129496402878 random_state 24
# accuracy 0.802158273381295 random_state 25
# accuracy 0.762589928057554 random_state 26
# accuracy 0.7553956834532374 random_state 27
# accuracy 0.7733812949640287 random_state 28
# accuracy 0.7733812949640287 random_state 29
# accuracy 0.8057553956834532 random_state 30
# accuracy 0.7482014388489209 random_state 31
# accuracy 0.7589928057553957 random_state 32
# accuracy 0.8057553956834532 random_state 33
# accuracy 0.762589928057554 random_state 34
# accuracy 0.7410071942446043 random_state 35
# accuracy 0.7553956834532374 random_state 36
# accuracy 0.7841726618705036 random_state 37
# accuracy 0.7805755395683454 random_state 38
# accuracy 0.7949640287769785 random_state 39
# accuracy 0.762589928057554 random_state 40
# accuracy 0.7517985611510791 random_state 41
# accuracy 0.7985611510791367 random_state 42
# accuracy 0.737410071942446 random_state 43
# accuracy 0.7769784172661871 random_state 44
# accuracy 0.7805755395683454 random_state 45
# accuracy 0.7805755395683454 random_state 46
# accuracy 0.7589928057553957 random_state 47
# accuracy 0.7949640287769785 random_state 48
# accuracy 0.7841726618705036 random_state 49
# accuracy 0.802158273381295 random_state 50
# accuracy 0.7805755395683454 random_state 51
# accuracy 0.7482014388489209 random_state 52
# accuracy 0.7733812949640287 random_state 53
# accuracy 0.8165467625899281 random_state 54
# accuracy 0.8057553956834532 random_state 55
# accuracy 0.841726618705036 random_state 56
# accuracy 0.7697841726618705 random_state 57
# accuracy 0.7661870503597122 random_state 58
# accuracy 0.7877697841726619 random_state 59
# accuracy 0.7913669064748201 random_state 60
# accuracy 0.7553956834532374 random_state 61
# accuracy 0.7266187050359713 random_state 62
# accuracy 0.7661870503597122 random_state 63
# accuracy 0.7661870503597122 random_state 64
# accuracy 0.7553956834532374 random_state 65
# accuracy 0.7733812949640287 random_state 66
# accuracy 0.8237410071942446 random_state 67
# accuracy 0.7913669064748201 random_state 68
# accuracy 0.7517985611510791 random_state 69
# accuracy 0.7877697841726619 random_state 70
# accuracy 0.7841726618705036 random_state 71
# accuracy 0.7985611510791367 random_state 72
# accuracy 0.7913669064748201 random_state 73
# accuracy 0.7482014388489209 random_state 74
# accuracy 0.7949640287769785 random_state 75
# accuracy 0.7841726618705036 random_state 76
# accuracy 0.7985611510791367 random_state 77
# accuracy 0.7949640287769785 random_state 78
# accuracy 0.762589928057554 random_state 79
# accuracy 0.7877697841726619 random_state 80
# accuracy 0.7949640287769785 random_state 81
# accuracy 0.7877697841726619 random_state 82
# accuracy 0.8057553956834532 random_state 83
# accuracy 0.8201438848920863 random_state 84
# accuracy 0.7985611510791367 random_state 85
# accuracy 0.802158273381295 random_state 86
# accuracy 0.7553956834532374 random_state 87
# accuracy 0.7697841726618705 random_state 88
# accuracy 0.7661870503597122 random_state 89
# accuracy 0.8345323741007195 random_state 90
# accuracy 0.7733812949640287 random_state 91
# accuracy 0.7949640287769785 random_state 92
# accuracy 0.7877697841726619 random_state 93
# accuracy 0.7697841726618705 random_state 94
# accuracy 0.7805755395683454 random_state 95
# accuracy 0.7517985611510791 random_state 96
# accuracy 0.7661870503597122 random_state 97
# accuracy 0.8057553956834532 random_state 98
# accuracy 0.8345323741007195 random_state 99
# accuracy 0.7302158273381295 random_state 100
# accuracy 0.7733812949640287 random_state 101
# accuracy 0.737410071942446 random_state 102
# accuracy 0.7482014388489209 random_state 103
# accuracy 0.7553956834532374 random_state 104
# accuracy 0.7877697841726619 random_state 105
# accuracy 0.802158273381295 random_state 106
# accuracy 0.7877697841726619 random_state 107
# accuracy 0.7338129496402878 random_state 108
# accuracy 0.8093525179856115 random_state 109
# accuracy 0.8165467625899281 random_state 110
# accuracy 0.7733812949640287 random_state 111
# accuracy 0.7805755395683454 random_state 112
# accuracy 0.7517985611510791 random_state 113
# accuracy 0.8165467625899281 random_state 114
# accuracy 0.7589928057553957 random_state 115
# accuracy 0.762589928057554 random_state 116
# accuracy 0.7769784172661871 random_state 117
# accuracy 0.7733812949640287 random_state 118
# accuracy 0.7661870503597122 random_state 119
# accuracy 0.7589928057553957 random_state 120
# accuracy 0.7553956834532374 random_state 121
# accuracy 0.7769784172661871 random_state 122
# accuracy 0.7841726618705036 random_state 123
# accuracy 0.7446043165467626 random_state 124
# accuracy 0.7661870503597122 random_state 125
# accuracy 0.7985611510791367 random_state 126
# accuracy 0.8057553956834532 random_state 127
# accuracy 0.737410071942446 random_state 128
# accuracy 0.802158273381295 random_state 129
# accuracy 0.7410071942446043 random_state 130
# accuracy 0.7949640287769785 random_state 131
# accuracy 0.7553956834532374 random_state 132
# accuracy 0.7661870503597122 random_state 133
# accuracy 0.7589928057553957 random_state 134
# accuracy 0.7985611510791367 random_state 135
# accuracy 0.7949640287769785 random_state 136
# accuracy 0.7841726618705036 random_state 137
# accuracy 0.7194244604316546 random_state 138
# accuracy 0.7913669064748201 random_state 139
# accuracy 0.7266187050359713 random_state 140
# accuracy 0.802158273381295 random_state 141
# accuracy 0.7302158273381295 random_state 142
# accuracy 0.7517985611510791 random_state 143
# accuracy 0.8201438848920863 random_state 144
# accuracy 0.7769784172661871 random_state 145
# accuracy 0.8309352517985612 random_state 146
# accuracy 0.7482014388489209 random_state 147
# accuracy 0.802158273381295 random_state 148
# accuracy 0.8057553956834532 random_state 149
# accuracy 0.7661870503597122 random_state 150
# accuracy 0.7517985611510791 random_state 151
# accuracy 0.7733812949640287 random_state 152
# accuracy 0.7841726618705036 random_state 153
# accuracy 0.7949640287769785 random_state 154
# accuracy 0.7697841726618705 random_state 155
# accuracy 0.7553956834532374 random_state 156
# accuracy 0.7949640287769785 random_state 157
# accuracy 0.762589928057554 random_state 158
# accuracy 0.7913669064748201 random_state 159
# accuracy 0.762589928057554 random_state 160
# accuracy 0.7877697841726619 random_state 161
# accuracy 0.7517985611510791 random_state 162
# accuracy 0.7733812949640287 random_state 163
# accuracy 0.7410071942446043 random_state 164
# accuracy 0.7877697841726619 random_state 165
# accuracy 0.7661870503597122 random_state 166
# accuracy 0.7086330935251799 random_state 167
# accuracy 0.7841726618705036 random_state 168
# accuracy 0.7769784172661871 random_state 169
# accuracy 0.7949640287769785 random_state 170
# accuracy 0.7697841726618705 random_state 171
# accuracy 0.7877697841726619 random_state 172
# accuracy 0.7482014388489209 random_state 173
# accuracy 0.7913669064748201 random_state 174
# accuracy 0.7661870503597122 random_state 175
# accuracy 0.7697841726618705 random_state 176
# accuracy 0.7913669064748201 random_state 177
# accuracy 0.8057553956834532 random_state 178
# accuracy 0.762589928057554 random_state 179
# accuracy 0.7985611510791367 random_state 180
# accuracy 0.7805755395683454 random_state 181
# accuracy 0.8093525179856115 random_state 182
# accuracy 0.7661870503597122 random_state 183
# accuracy 0.7697841726618705 random_state 184
# accuracy 0.7733812949640287 random_state 185
# accuracy 0.7913669064748201 random_state 186
# accuracy 0.7877697841726619 random_state 187
# accuracy 0.7769784172661871 random_state 188
# accuracy 0.7769784172661871 random_state 189
# accuracy 0.7733812949640287 random_state 190
# accuracy 0.7589928057553957 random_state 191
# accuracy 0.7949640287769785 random_state 192
# accuracy 0.7302158273381295 random_state 193
# accuracy 0.8237410071942446 random_state 194
# accuracy 0.7661870503597122 random_state 195
# accuracy 0.7805755395683454 random_state 196
# accuracy 0.7589928057553957 random_state 197
# accuracy 0.7553956834532374 random_state 198
# accuracy 0.802158273381295 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.841726618705036 On Random_state  56

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    def svmkernel(ker):
        svc = SVC(kernel=ker)
        svc.fit(x_train,y_train)
        pred = svc.predict(x_test)
        acc = accuracy_score(y_test, pred)
        print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i

# %%
svmkernel('rbf')
# Out:
# accuracy 0.8741007194244604 random_state 199

# %%
svmkernel('poly')
# Out:
# accuracy 0.8633093525179856 random_state 199

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    gnb = GaussianNB()
    gnb.fit(x_train,y_train)
    pred = gnb.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.7697841726618705 random_state 1
# accuracy 0.8309352517985612 random_state 2
# accuracy 0.7805755395683454 random_state 3
# accuracy 0.762589928057554 random_state 4
# accuracy 0.7697841726618705 random_state 5
# accuracy 0.8741007194244604 random_state 6
# accuracy 0.7733812949640287 random_state 7
# accuracy 0.7841726618705036 random_state 8
# accuracy 0.8489208633093526 random_state 9
# accuracy 0.762589928057554 random_state 10
# accuracy 0.7733812949640287 random_state 11
# accuracy 0.7697841726618705 random_state 12
# accuracy 0.7913669064748201 random_state 13
# accuracy 0.8201438848920863 random_state 14
# accuracy 0.7733812949640287 random_state 15
# accuracy 0.7769784172661871 random_state 16
# accuracy 0.7805755395683454 random_state 17
# accuracy 0.8129496402877698 random_state 18
# accuracy 0.7661870503597122 random_state 19
# accuracy 0.7841726618705036 random_state 20
# accuracy 0.7877697841726619 random_state 21
# accuracy 0.7446043165467626 random_state 22
# accuracy 0.8165467625899281 random_state 23
# accuracy 0.8309352517985612 random_state 24
# accuracy 0.7949640287769785 random_state 25
# accuracy 0.7661870503597122 random_state 26
# accuracy 0.802158273381295 random_state 27
# accuracy 0.8237410071942446 random_state 28
# accuracy 0.7733812949640287 random_state 29
# accuracy 0.7985611510791367 random_state 30
# accuracy 0.7697841726618705 random_state 31
# accuracy 0.8201438848920863 random_state 32
# accuracy 0.8057553956834532 random_state 33
# accuracy 0.7805755395683454 random_state 34
# accuracy 0.7913669064748201 random_state 35
# accuracy 0.762589928057554 random_state 36
# accuracy 0.7949640287769785 random_state 37
# accuracy 0.7877697841726619 random_state 38
# accuracy 0.7553956834532374 random_state 39
# accuracy 0.802158273381295 random_state 40
# accuracy 0.8093525179856115 random_state 41
# accuracy 0.7482014388489209 random_state 42
# accuracy 0.7410071942446043 random_state 43
# accuracy 0.802158273381295 random_state 44
# accuracy 0.7805755395683454 random_state 45
# accuracy 0.737410071942446 random_state 46
# accuracy 0.8093525179856115 random_state 47
# accuracy 0.8237410071942446 random_state 48
# accuracy 0.7949640287769785 random_state 49
# accuracy 0.7985611510791367 random_state 50
# accuracy 0.7697841726618705 random_state 51
# accuracy 0.7302158273381295 random_state 52
# accuracy 0.7913669064748201 random_state 53
# accuracy 0.8165467625899281 random_state 54
# accuracy 0.8453237410071942 random_state 55
# accuracy 0.7985611510791367 random_state 56
# accuracy 0.8309352517985612 random_state 57
# accuracy 0.7805755395683454 random_state 58
# accuracy 0.7985611510791367 random_state 59
# accuracy 0.8129496402877698 random_state 60
# accuracy 0.7913669064748201 random_state 61
# accuracy 0.7697841726618705 random_state 62
# accuracy 0.7697841726618705 random_state 63
# accuracy 0.7985611510791367 random_state 64
# accuracy 0.7913669064748201 random_state 65
# accuracy 0.7805755395683454 random_state 66
# accuracy 0.8165467625899281 random_state 67
# accuracy 0.7769784172661871 random_state 68
# accuracy 0.8057553956834532 random_state 69
# accuracy 0.7697841726618705 random_state 70
# accuracy 0.8345323741007195 random_state 71
# accuracy 0.8309352517985612 random_state 72
# accuracy 0.7877697841726619 random_state 73
# accuracy 0.7805755395683454 random_state 74
# accuracy 0.8093525179856115 random_state 75
# accuracy 0.7949640287769785 random_state 76
# accuracy 0.7661870503597122 random_state 77
# accuracy 0.7841726618705036 random_state 78
# accuracy 0.7769784172661871 random_state 79
# accuracy 0.7517985611510791 random_state 80
# accuracy 0.7841726618705036 random_state 81
# accuracy 0.7841726618705036 random_state 82
# accuracy 0.7769784172661871 random_state 83
# accuracy 0.802158273381295 random_state 84
# accuracy 0.7877697841726619 random_state 85
# accuracy 0.7877697841726619 random_state 86
# accuracy 0.737410071942446 random_state 87
# accuracy 0.7985611510791367 random_state 88
# accuracy 0.7985611510791367 random_state 89
# accuracy 0.8345323741007195 random_state 90
# accuracy 0.7805755395683454 random_state 91
# accuracy 0.7805755395683454 random_state 92
# accuracy 0.802158273381295 random_state 93
# accuracy 0.7985611510791367 random_state 94
# accuracy 0.7805755395683454 random_state 95
# accuracy 0.7949640287769785 random_state 96
# accuracy 0.7769784172661871 random_state 97
# accuracy 0.8129496402877698 random_state 98
# accuracy 0.762589928057554 random_state 99
# accuracy 0.7697841726618705 random_state 100
# accuracy 0.7769784172661871 random_state 101
# accuracy 0.7697841726618705 random_state 102
# accuracy 0.8093525179856115 random_state 103
# accuracy 0.7338129496402878 random_state 104
# accuracy 0.7086330935251799 random_state 105
# accuracy 0.8381294964028777 random_state 106
# accuracy 0.7661870503597122 random_state 107
# accuracy 0.7769784172661871 random_state 108
# accuracy 0.802158273381295 random_state 109
# accuracy 0.8129496402877698 random_state 110
# accuracy 0.7589928057553957 random_state 111
# accuracy 0.802158273381295 random_state 112
# accuracy 0.7661870503597122 random_state 113
# accuracy 0.802158273381295 random_state 114
# accuracy 0.7877697841726619 random_state 115
# accuracy 0.8237410071942446 random_state 116
# accuracy 0.7949640287769785 random_state 117
# accuracy 0.7949640287769785 random_state 118
# accuracy 0.7661870503597122 random_state 119
# accuracy 0.7985611510791367 random_state 120
# accuracy 0.8561151079136691 random_state 121
# accuracy 0.762589928057554 random_state 122
# accuracy 0.7985611510791367 random_state 123
# accuracy 0.7697841726618705 random_state 124
# accuracy 0.7985611510791367 random_state 125
# accuracy 0.7841726618705036 random_state 126
# accuracy 0.7589928057553957 random_state 127
# accuracy 0.737410071942446 random_state 128
# accuracy 0.7769784172661871 random_state 129
# accuracy 0.7517985611510791 random_state 130
# accuracy 0.7841726618705036 random_state 131
# accuracy 0.762589928057554 random_state 132
# accuracy 0.7661870503597122 random_state 133
# accuracy 0.7805755395683454 random_state 134
# accuracy 0.7877697841726619 random_state 135
# accuracy 0.802158273381295 random_state 136
# accuracy 0.7589928057553957 random_state 137
# accuracy 0.8129496402877698 random_state 138
# accuracy 0.8057553956834532 random_state 139
# accuracy 0.762589928057554 random_state 140
# accuracy 0.7841726618705036 random_state 141
# accuracy 0.7949640287769785 random_state 142
# accuracy 0.7158273381294964 random_state 143
# accuracy 0.8165467625899281 random_state 144
# accuracy 0.7913669064748201 random_state 145
# accuracy 0.7985611510791367 random_state 146
# accuracy 0.7805755395683454 random_state 147
# accuracy 0.8129496402877698 random_state 148
# accuracy 0.7985611510791367 random_state 149
# accuracy 0.8129496402877698 random_state 150
# accuracy 0.7446043165467626 random_state 151
# accuracy 0.7697841726618705 random_state 152
# accuracy 0.7661870503597122 random_state 153
# accuracy 0.8057553956834532 random_state 154
# accuracy 0.7805755395683454 random_state 155
# accuracy 0.7697841726618705 random_state 156
# accuracy 0.802158273381295 random_state 157
# accuracy 0.7949640287769785 random_state 158
# accuracy 0.7733812949640287 random_state 159
# accuracy 0.7949640287769785 random_state 160
# accuracy 0.7769784172661871 random_state 161
# accuracy 0.762589928057554 random_state 162
# accuracy 0.8237410071942446 random_state 163
# accuracy 0.7985611510791367 random_state 164
# accuracy 0.7769784172661871 random_state 165
# accuracy 0.7841726618705036 random_state 166
# accuracy 0.8201438848920863 random_state 167
# accuracy 0.7482014388489209 random_state 168
# accuracy 0.8057553956834532 random_state 169
# accuracy 0.8093525179856115 random_state 170
# accuracy 0.7733812949640287 random_state 171
# accuracy 0.8201438848920863 random_state 172
# accuracy 0.7158273381294964 random_state 173
# accuracy 0.7661870503597122 random_state 174
# accuracy 0.7949640287769785 random_state 175
# accuracy 0.7446043165467626 random_state 176
# accuracy 0.7805755395683454 random_state 177
# accuracy 0.737410071942446 random_state 178
# accuracy 0.7841726618705036 random_state 179
# accuracy 0.737410071942446 random_state 180
# accuracy 0.8093525179856115 random_state 181
# accuracy 0.8093525179856115 random_state 182
# accuracy 0.8201438848920863 random_state 183
# accuracy 0.7913669064748201 random_state 184
# accuracy 0.762589928057554 random_state 185
# accuracy 0.7697841726618705 random_state 186
# accuracy 0.7877697841726619 random_state 187
# accuracy 0.7841726618705036 random_state 188
# accuracy 0.7589928057553957 random_state 189
# accuracy 0.762589928057554 random_state 190
# accuracy 0.7805755395683454 random_state 191
# accuracy 0.762589928057554 random_state 192
# accuracy 0.7913669064748201 random_state 193
# accuracy 0.7589928057553957 random_state 194
# accuracy 0.7949640287769785 random_state 195
# accuracy 0.7949640287769785 random_state 196
# accuracy 0.7589928057553957 random_state 197
# accuracy 0.7877697841726619 random_state 198
# accuracy 0.8093525179856115 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.8741007194244604 On Random_state  6

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    knn = KNeighborsClassifier()
    knn.fit(x_train,y_train)
    pred = knn.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.8309352517985612 random_state 1
# accuracy 0.8597122302158273 random_state 2
# accuracy 0.8741007194244604 random_state 3
# accuracy 0.8345323741007195 random_state 4
# accuracy 0.8309352517985612 random_state 5
# accuracy 0.841726618705036 random_state 6
# accuracy 0.8525179856115108 random_state 7
# accuracy 0.8381294964028777 random_state 8
# accuracy 0.8273381294964028 random_state 9
# accuracy 0.8381294964028777 random_state 10
# accuracy 0.8489208633093526 random_state 11
# accuracy 0.802158273381295 random_state 12
# accuracy 0.8489208633093526 random_state 13
# accuracy 0.8093525179856115 random_state 14
# accuracy 0.8273381294964028 random_state 15
# accuracy 0.8093525179856115 random_state 16
# accuracy 0.8201438848920863 random_state 17
# accuracy 0.8237410071942446 random_state 18
# accuracy 0.8489208633093526 random_state 19
# accuracy 0.8345323741007195 random_state 20
# accuracy 0.8237410071942446 random_state 21
# accuracy 0.8381294964028777 random_state 22
# accuracy 0.8237410071942446 random_state 23
# accuracy 0.8165467625899281 random_state 24
# accuracy 0.8525179856115108 random_state 25
# accuracy 0.8453237410071942 random_state 26
# accuracy 0.8129496402877698 random_state 27
# accuracy 0.8201438848920863 random_state 28
# accuracy 0.841726618705036 random_state 29
# accuracy 0.8597122302158273 random_state 30
# accuracy 0.8165467625899281 random_state 31
# accuracy 0.8812949640287769 random_state 32
# accuracy 0.8165467625899281 random_state 33
# accuracy 0.841726618705036 random_state 34
# accuracy 0.8201438848920863 random_state 35
# accuracy 0.8381294964028777 random_state 36
# accuracy 0.8237410071942446 random_state 37
# accuracy 0.8201438848920863 random_state 38
# accuracy 0.8309352517985612 random_state 39
# accuracy 0.7985611510791367 random_state 40
# accuracy 0.841726618705036 random_state 41
# accuracy 0.8273381294964028 random_state 42
# accuracy 0.8453237410071942 random_state 43
# accuracy 0.8561151079136691 random_state 44
# accuracy 0.8741007194244604 random_state 45
# accuracy 0.8273381294964028 random_state 46
# accuracy 0.8273381294964028 random_state 47
# accuracy 0.8776978417266187 random_state 48
# accuracy 0.8489208633093526 random_state 49
# accuracy 0.8561151079136691 random_state 50
# accuracy 0.8597122302158273 random_state 51
# accuracy 0.8345323741007195 random_state 52
# accuracy 0.8129496402877698 random_state 53
# accuracy 0.8273381294964028 random_state 54
# accuracy 0.8597122302158273 random_state 55
# accuracy 0.8633093525179856 random_state 56
# accuracy 0.8741007194244604 random_state 57
# accuracy 0.841726618705036 random_state 58
# accuracy 0.8273381294964028 random_state 59
# accuracy 0.8201438848920863 random_state 60
# accuracy 0.8309352517985612 random_state 61
# accuracy 0.8525179856115108 random_state 62
# accuracy 0.8669064748201439 random_state 63
# accuracy 0.8345323741007195 random_state 64
# accuracy 0.802158273381295 random_state 65
# accuracy 0.8525179856115108 random_state 66
# accuracy 0.8525179856115108 random_state 67
# accuracy 0.8309352517985612 random_state 68
# accuracy 0.8669064748201439 random_state 69
# accuracy 0.8309352517985612 random_state 70
# accuracy 0.8561151079136691 random_state 71
# accuracy 0.8633093525179856 random_state 72
# accuracy 0.8453237410071942 random_state 73
# accuracy 0.8201438848920863 random_state 74
# accuracy 0.8165467625899281 random_state 75
# accuracy 0.8812949640287769 random_state 76
# accuracy 0.8345323741007195 random_state 77
# accuracy 0.8345323741007195 random_state 78
# accuracy 0.8453237410071942 random_state 79
# accuracy 0.8561151079136691 random_state 80
# accuracy 0.8812949640287769 random_state 81
# accuracy 0.8345323741007195 random_state 82
# accuracy 0.8489208633093526 random_state 83
# accuracy 0.841726618705036 random_state 84
# accuracy 0.8489208633093526 random_state 85
# accuracy 0.8345323741007195 random_state 86
# accuracy 0.8309352517985612 random_state 87
# accuracy 0.8237410071942446 random_state 88
# accuracy 0.8453237410071942 random_state 89
# accuracy 0.8309352517985612 random_state 90
# accuracy 0.8597122302158273 random_state 91
# accuracy 0.8669064748201439 random_state 92
# accuracy 0.841726618705036 random_state 93
# accuracy 0.8273381294964028 random_state 94
# accuracy 0.8273381294964028 random_state 95
# accuracy 0.8165467625899281 random_state 96
# accuracy 0.8237410071942446 random_state 97
# accuracy 0.8237410071942446 random_state 98
# accuracy 0.8597122302158273 random_state 99
# accuracy 0.8237410071942446 random_state 100
# accuracy 0.841726618705036 random_state 101
# accuracy 0.8129496402877698 random_state 102
# accuracy 0.8345323741007195 random_state 103
# accuracy 0.7949640287769785 random_state 104
# accuracy 0.8237410071942446 random_state 105
# accuracy 0.8812949640287769 random_state 106
# accuracy 0.8597122302158273 random_state 107
# accuracy 0.7805755395683454 random_state 108
# accuracy 0.8705035971223022 random_state 109
# accuracy 0.8309352517985612 random_state 110
# accuracy 0.8489208633093526 random_state 111
# accuracy 0.8381294964028777 random_state 112
# accuracy 0.8381294964028777 random_state 113
# accuracy 0.8848920863309353 random_state 114
# accuracy 0.8453237410071942 random_state 115
# accuracy 0.8489208633093526 random_state 116
# accuracy 0.8525179856115108 random_state 117
# accuracy 0.8345323741007195 random_state 118
# accuracy 0.8597122302158273 random_state 119
# accuracy 0.8489208633093526 random_state 120
# accuracy 0.8237410071942446 random_state 121
# accuracy 0.8273381294964028 random_state 122
# accuracy 0.8489208633093526 random_state 123
# accuracy 0.8381294964028777 random_state 124
# accuracy 0.8237410071942446 random_state 125
# accuracy 0.9064748201438849 random_state 126
# accuracy 0.8273381294964028 random_state 127
# accuracy 0.8093525179856115 random_state 128
# accuracy 0.8237410071942446 random_state 129
# accuracy 0.8309352517985612 random_state 130
# accuracy 0.802158273381295 random_state 131
# accuracy 0.8165467625899281 random_state 132
# accuracy 0.8273381294964028 random_state 133
# accuracy 0.8561151079136691 random_state 134
# accuracy 0.8597122302158273 random_state 135
# accuracy 0.8489208633093526 random_state 136
# accuracy 0.8129496402877698 random_state 137
# accuracy 0.7949640287769785 random_state 138
# accuracy 0.8525179856115108 random_state 139
# accuracy 0.841726618705036 random_state 140
# accuracy 0.8309352517985612 random_state 141
# accuracy 0.7841726618705036 random_state 142
# accuracy 0.841726618705036 random_state 143
# accuracy 0.8309352517985612 random_state 144
# accuracy 0.8381294964028777 random_state 145
# accuracy 0.8489208633093526 random_state 146
# accuracy 0.8345323741007195 random_state 147
# accuracy 0.8345323741007195 random_state 148
# accuracy 0.8201438848920863 random_state 149
# accuracy 0.8381294964028777 random_state 150
# accuracy 0.8237410071942446 random_state 151
# accuracy 0.8525179856115108 random_state 152
# accuracy 0.8669064748201439 random_state 153
# accuracy 0.8525179856115108 random_state 154
# accuracy 0.8489208633093526 random_state 155
# accuracy 0.8453237410071942 random_state 156
# accuracy 0.8561151079136691 random_state 157
# accuracy 0.841726618705036 random_state 158
# accuracy 0.8453237410071942 random_state 159
# accuracy 0.8489208633093526 random_state 160
# accuracy 0.8237410071942446 random_state 161
# accuracy 0.8201438848920863 random_state 162
# accuracy 0.8453237410071942 random_state 163
# accuracy 0.8848920863309353 random_state 164
# accuracy 0.8165467625899281 random_state 165
# accuracy 0.8633093525179856 random_state 166
# accuracy 0.8093525179856115 random_state 167
# accuracy 0.8309352517985612 random_state 168
# accuracy 0.7877697841726619 random_state 169
# accuracy 0.8633093525179856 random_state 170
# accuracy 0.8345323741007195 random_state 171
# accuracy 0.8561151079136691 random_state 172
# accuracy 0.8165467625899281 random_state 173
# accuracy 0.8057553956834532 random_state 174
# accuracy 0.8489208633093526 random_state 175
# accuracy 0.8848920863309353 random_state 176
# accuracy 0.8453237410071942 random_state 177
# accuracy 0.8453237410071942 random_state 178
# accuracy 0.841726618705036 random_state 179
# accuracy 0.8597122302158273 random_state 180
# accuracy 0.8633093525179856 random_state 181
# accuracy 0.8453237410071942 random_state 182
# accuracy 0.8093525179856115 random_state 183
# accuracy 0.841726618705036 random_state 184
# accuracy 0.8273381294964028 random_state 185
# accuracy 0.8381294964028777 random_state 186
# accuracy 0.8525179856115108 random_state 187
# accuracy 0.8561151079136691 random_state 188
# accuracy 0.8381294964028777 random_state 189
# accuracy 0.8345323741007195 random_state 190
# accuracy 0.8633093525179856 random_state 191
# accuracy 0.8453237410071942 random_state 192
# accuracy 0.841726618705036 random_state 193
# accuracy 0.841726618705036 random_state 194
# accuracy 0.8705035971223022 random_state 195
# accuracy 0.8129496402877698 random_state 196
# accuracy 0.8309352517985612 random_state 197
# accuracy 0.8129496402877698 random_state 198
# accuracy 0.8741007194244604 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.9064748201438849 On Random_state  126

# %% [markdown]
# # Creating train-test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.20,random_state = 6)

# %%
x_train
# Out:
# array([[-0.90535412, -0.40407506, -0.49633675, ...,  2.89127199,
#          0.36826963,  1.10257488],
#        [ 0.59312579,  0.35417322, -0.49633675, ..., -0.71069889,
#         -0.55262577, -1.274179  ],
#        [ 0.59312579, -1.40322514, -2.39804688, ..., -0.71069889,
#         -1.16655603, -1.38735776],
#        ...,
#        [ 0.59312579, -1.37163146, -0.49633675, ..., -0.31047991,
#          0.9821999 ,  0.98939612],
#        [ 0.59312579,  0.66616079,  1.40537338, ..., -0.71069889,
#          0.0613045 ,  2.57389871],
#        [ 0.59312579,  0.50424319,  1.40537338, ..., -0.31047991,
#          0.9821999 ,  0.19714483]])

# %%
x_test
# Out:
# array([[ 0.59312579, -0.54624661,  1.40537338, ..., -0.71069889,
#          1.28916503, -0.36874895],
#        [ 0.59312579, -0.2579543 , -0.49633675, ..., -0.31047991,
#         -0.55262577,  0.19714483],
#        [ 0.59312579, -1.62833009, -0.49633675, ..., -0.71069889,
#          1.28916503,  2.12118368],
#        ...,
#        [ 0.59312579,  1.26644068, -0.49633675, ..., -0.31047991,
#         -0.55262577, -1.50053652],
#        [ 0.59312579, -1.48220933,  1.40537338, ..., -0.71069889,
#          0.67523477, -0.2555702 ],
#        [ 0.59312579,  0.70170368,  1.40537338, ...,  0.48995807,
#          1.9030953 ,  0.87621736]])

# %%
y_train
# Out:
# 93      0
# 1003    0
# 1222    1
# 615     0
# 1065    0
#        ..
# 355     0
# 656     1
# 244     0
# 758     0
# 963     0
# Name: Attrition, Length: 1109, dtype: int32

# %%
y_test
# Out:
# 619     0
# 287     0
# 283     0
# 777     1
# 711     1
#        ..
# 1100    0
# 91      0
# 1201    1
# 494     0
# 907     0
# Name: Attrition, Length: 278, dtype: int32

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (1387, 30) (1109, 30) (278, 30)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (1387,) (1109,) (278,)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       240
#            1       0.08      0.05      0.06        38
#
#     accuracy                           0.79       278
#    macro avg       0.47      0.48      0.47       278
# weighted avg       0.75      0.79      0.77       278

# %% [markdown]
# # Cross validation score for logistic regression

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss = accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc = lsscore.mean()
    print("At cv:-",j)
    print("cross validation score is :-",lsc*100)
    print("accuracy_score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# cross validation score is :- 86.5175010708152
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 3
# cross validation score is :- 86.73358079405595
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 4
# cross validation score is :- 86.66168313038263
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 5
# cross validation score is :- 87.23813728800354
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 6
# cross validation score is :- 86.80462258048465
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 7
# cross validation score is :- 87.0927509118464
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 8
# cross validation score is :- 86.87711779948177
# accuracy_score is :- 91.72661870503596
#
#
# At cv:- 9
# cross validation score is :- 86.73183447376996
# accuracy_score is :- 91.72661870503596

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=5).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.8723813728800354
# The accuracy score is:  0.9172661870503597

# %% [markdown]
# # AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, threshold = roc_curve(y_test,pred)
roc_auc = auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color = 'darkorange', lw=10, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0,1],[0,1], color='navy', lw=10, linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename = 'employee_attrition.pkl'
pickle.dump(rfc,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(lr.predict(x_test))
df_comp = pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
df_comp
# Out:
#      original  predicted
# 0           0          0
# 1           0          0
# 2           0          0
# 3           1          1
# 4           1          1
# ..        ...        ...
# 273         0          0
# 274         0          0
# 275         1          0
# 276         0          0
# 277         0          0
#
# [278 rows x 2 columns]
