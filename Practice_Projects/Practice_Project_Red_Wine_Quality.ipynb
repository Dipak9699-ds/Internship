# %% [markdown]
# # importing required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # loading the dataset

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#checking data dimension
df.shape
# Out:
# (1599, 12)

# %%
#display columns of dataframe
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#display datatypes of columns
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
#display information of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#display sum of null values in columns
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#display heatmap of null values in columns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Analysis and Visulaization

# %%
#statistical summary.
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#number of values for each quality.
sns.countplot(x='quality',data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
#citric acid vs Quality
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='citric acid', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
corr_mat = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_mat, annot=True, fmt = '.1f',cmap = 'Blues')
plt.title('Correlation matrix')
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
type(corr_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_matrix = df.corr()
corr_matrix['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %%
# Let's check the data distribution among all the columns
df.plot(kind='density', subplots=True, layout=(3,4), sharex=False, legend=True, fontsize=1, figsize=(18,12))
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
#Splitting the independent and target variable in x and y before removing the skewness
x = df.drop("quality",axis=1)
print(x)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %% [markdown]
# # Label Binarization

# %%
y = df['quality'].apply(lambda y_value: 1 if y_value >=7 else 0)
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # Training process begins

# %% [markdown]
# ### Finding best random_state

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    rfc = RandomForestClassifier()
    rfc.fit(x_train,y_train)
    pred = rfc.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.925 random_state 1
# accuracy 0.925 random_state 2
# accuracy 0.928125 random_state 3
# accuracy 0.915625 random_state 4
# accuracy 0.90625 random_state 5
# accuracy 0.921875 random_state 6
# accuracy 0.896875 random_state 7
# accuracy 0.91875 random_state 8
# accuracy 0.915625 random_state 9
# accuracy 0.89375 random_state 10
# accuracy 0.9125 random_state 11
# accuracy 0.9 random_state 12
# accuracy 0.921875 random_state 13
# accuracy 0.903125 random_state 14
# accuracy 0.928125 random_state 15
# accuracy 0.909375 random_state 16
# accuracy 0.925 random_state 17
# accuracy 0.909375 random_state 18
# accuracy 0.90625 random_state 19
# accuracy 0.9 random_state 20
# accuracy 0.93125 random_state 21
# accuracy 0.915625 random_state 22
# accuracy 0.9 random_state 23
# accuracy 0.909375 random_state 24
# accuracy 0.921875 random_state 25
# accuracy 0.928125 random_state 26
# accuracy 0.9125 random_state 27
# accuracy 0.909375 random_state 28
# accuracy 0.9 random_state 29
# accuracy 0.9125 random_state 30
# accuracy 0.915625 random_state 31
# accuracy 0.915625 random_state 32
# accuracy 0.934375 random_state 33
# accuracy 0.896875 random_state 34
# accuracy 0.90625 random_state 35
# accuracy 0.89375 random_state 36
# accuracy 0.928125 random_state 37
# accuracy 0.93125 random_state 38
# accuracy 0.9 random_state 39
# accuracy 0.90625 random_state 40
# accuracy 0.934375 random_state 41
# accuracy 0.9 random_state 42
# accuracy 0.925 random_state 43
# accuracy 0.896875 random_state 44
# accuracy 0.9125 random_state 45
# accuracy 0.903125 random_state 46
# accuracy 0.909375 random_state 47
# accuracy 0.921875 random_state 48
# accuracy 0.89375 random_state 49
# accuracy 0.953125 random_state 50
# accuracy 0.925 random_state 51
# accuracy 0.90625 random_state 52
# accuracy 0.909375 random_state 53
# accuracy 0.928125 random_state 54
# accuracy 0.909375 random_state 55
# accuracy 0.91875 random_state 56
# accuracy 0.925 random_state 57
# accuracy 0.91875 random_state 58
# accuracy 0.9125 random_state 59
# accuracy 0.9 random_state 60
# accuracy 0.9125 random_state 61
# accuracy 0.91875 random_state 62
# accuracy 0.88125 random_state 63
# accuracy 0.903125 random_state 64
# accuracy 0.909375 random_state 65
# accuracy 0.903125 random_state 66
# accuracy 0.934375 random_state 67
# accuracy 0.921875 random_state 68
# accuracy 0.89375 random_state 69
# accuracy 0.93125 random_state 70
# accuracy 0.90625 random_state 71
# accuracy 0.915625 random_state 72
# accuracy 0.925 random_state 73
# accuracy 0.915625 random_state 74
# accuracy 0.9 random_state 75
# accuracy 0.9 random_state 76
# accuracy 0.909375 random_state 77
# accuracy 0.91875 random_state 78
# accuracy 0.884375 random_state 79
# accuracy 0.884375 random_state 80
# accuracy 0.896875 random_state 81
# accuracy 0.909375 random_state 82
# accuracy 0.9 random_state 83
# accuracy 0.91875 random_state 84
# accuracy 0.909375 random_state 85
# accuracy 0.940625 random_state 86
# accuracy 0.921875 random_state 87
# accuracy 0.915625 random_state 88
# accuracy 0.896875 random_state 89
# accuracy 0.91875 random_state 90
# accuracy 0.88125 random_state 91
# accuracy 0.94375 random_state 92
# accuracy 0.921875 random_state 93
# accuracy 0.928125 random_state 94
# accuracy 0.90625 random_state 95
# accuracy 0.90625 random_state 96
# accuracy 0.915625 random_state 97
# accuracy 0.890625 random_state 98
# accuracy 0.9125 random_state 99
# accuracy 0.921875 random_state 100
# accuracy 0.9 random_state 101
# accuracy 0.903125 random_state 102
# accuracy 0.9125 random_state 103
# accuracy 0.9 random_state 104
# accuracy 0.88125 random_state 105
# accuracy 0.9 random_state 106
# accuracy 0.928125 random_state 107
# accuracy 0.934375 random_state 108
# accuracy 0.90625 random_state 109
# accuracy 0.90625 random_state 110
# accuracy 0.9375 random_state 111
# accuracy 0.9125 random_state 112
# accuracy 0.903125 random_state 113
# accuracy 0.9 random_state 114
# accuracy 0.934375 random_state 115
# accuracy 0.9 random_state 116
# accuracy 0.90625 random_state 117
# accuracy 0.909375 random_state 118
# accuracy 0.9125 random_state 119
# accuracy 0.90625 random_state 120
# accuracy 0.9375 random_state 121
# accuracy 0.90625 random_state 122
# accuracy 0.9125 random_state 123
# accuracy 0.896875 random_state 124
# accuracy 0.915625 random_state 125
# accuracy 0.915625 random_state 126
# accuracy 0.921875 random_state 127
# accuracy 0.909375 random_state 128
# accuracy 0.896875 random_state 129
# accuracy 0.925 random_state 130
# accuracy 0.921875 random_state 131
# accuracy 0.925 random_state 132
# accuracy 0.890625 random_state 133
# accuracy 0.903125 random_state 134
# accuracy 0.915625 random_state 135
# accuracy 0.91875 random_state 136
# accuracy 0.925 random_state 137
# accuracy 0.9 random_state 138
# accuracy 0.896875 random_state 139
# accuracy 0.91875 random_state 140
# accuracy 0.928125 random_state 141
# accuracy 0.921875 random_state 142
# accuracy 0.90625 random_state 143
# accuracy 0.871875 random_state 144
# accuracy 0.903125 random_state 145
# accuracy 0.915625 random_state 146
# accuracy 0.909375 random_state 147
# accuracy 0.928125 random_state 148
# accuracy 0.890625 random_state 149
# accuracy 0.8875 random_state 150
# accuracy 0.896875 random_state 151
# accuracy 0.925 random_state 152
# accuracy 0.90625 random_state 153
# accuracy 0.89375 random_state 154
# accuracy 0.921875 random_state 155
# accuracy 0.88125 random_state 156
# accuracy 0.89375 random_state 157
# accuracy 0.909375 random_state 158
# accuracy 0.890625 random_state 159
# accuracy 0.909375 random_state 160
# accuracy 0.91875 random_state 161
# accuracy 0.903125 random_state 162
# accuracy 0.915625 random_state 163
# accuracy 0.884375 random_state 164
# accuracy 0.909375 random_state 165
# accuracy 0.890625 random_state 166
# accuracy 0.925 random_state 167
# accuracy 0.9 random_state 168
# accuracy 0.89375 random_state 169
# accuracy 0.91875 random_state 170
# accuracy 0.915625 random_state 171
# accuracy 0.90625 random_state 172
# accuracy 0.915625 random_state 173
# accuracy 0.90625 random_state 174
# accuracy 0.90625 random_state 175
# accuracy 0.934375 random_state 176
# accuracy 0.90625 random_state 177
# accuracy 0.903125 random_state 178
# accuracy 0.93125 random_state 179
# accuracy 0.89375 random_state 180
# accuracy 0.921875 random_state 181
# accuracy 0.915625 random_state 182
# accuracy 0.8875 random_state 183
# accuracy 0.9125 random_state 184
# accuracy 0.90625 random_state 185
# accuracy 0.925 random_state 186
# accuracy 0.928125 random_state 187
# accuracy 0.921875 random_state 188
# accuracy 0.896875 random_state 189
# accuracy 0.875 random_state 190
# accuracy 0.89375 random_state 191
# accuracy 0.925 random_state 192
# accuracy 0.928125 random_state 193
# accuracy 0.890625 random_state 194
# accuracy 0.921875 random_state 195
# accuracy 0.9125 random_state 196
# accuracy 0.925 random_state 197
# accuracy 0.890625 random_state 198
# accuracy 0.93125 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.953125 On Random_state  50

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.9 random_state 1
# accuracy 0.8875 random_state 2
# accuracy 0.89375 random_state 3
# accuracy 0.89375 random_state 4
# accuracy 0.86875 random_state 5
# accuracy 0.9 random_state 6
# accuracy 0.871875 random_state 7
# accuracy 0.890625 random_state 8
# accuracy 0.896875 random_state 9
# accuracy 0.86875 random_state 10
# accuracy 0.86875 random_state 11
# accuracy 0.871875 random_state 12
# accuracy 0.884375 random_state 13
# accuracy 0.859375 random_state 14
# accuracy 0.8875 random_state 15
# accuracy 0.903125 random_state 16
# accuracy 0.909375 random_state 17
# accuracy 0.875 random_state 18
# accuracy 0.859375 random_state 19
# accuracy 0.8625 random_state 20
# accuracy 0.875 random_state 21
# accuracy 0.878125 random_state 22
# accuracy 0.884375 random_state 23
# accuracy 0.865625 random_state 24
# accuracy 0.875 random_state 25
# accuracy 0.9 random_state 26
# accuracy 0.88125 random_state 27
# accuracy 0.8625 random_state 28
# accuracy 0.8625 random_state 29
# accuracy 0.875 random_state 30
# accuracy 0.871875 random_state 31
# accuracy 0.871875 random_state 32
# accuracy 0.878125 random_state 33
# accuracy 0.865625 random_state 34
# accuracy 0.859375 random_state 35
# accuracy 0.8625 random_state 36
# accuracy 0.896875 random_state 37
# accuracy 0.909375 random_state 38
# accuracy 0.834375 random_state 39
# accuracy 0.859375 random_state 40
# accuracy 0.8875 random_state 41
# accuracy 0.865625 random_state 42
# accuracy 0.88125 random_state 43
# accuracy 0.884375 random_state 44
# accuracy 0.86875 random_state 45
# accuracy 0.846875 random_state 46
# accuracy 0.86875 random_state 47
# accuracy 0.8875 random_state 48
# accuracy 0.871875 random_state 49
# accuracy 0.915625 random_state 50
# accuracy 0.90625 random_state 51
# accuracy 0.86875 random_state 52
# accuracy 0.890625 random_state 53
# accuracy 0.871875 random_state 54
# accuracy 0.88125 random_state 55
# accuracy 0.89375 random_state 56
# accuracy 0.88125 random_state 57
# accuracy 0.86875 random_state 58
# accuracy 0.890625 random_state 59
# accuracy 0.871875 random_state 60
# accuracy 0.853125 random_state 61
# accuracy 0.878125 random_state 62
# accuracy 0.86875 random_state 63
# accuracy 0.871875 random_state 64
# accuracy 0.884375 random_state 65
# accuracy 0.884375 random_state 66
# accuracy 0.9125 random_state 67
# accuracy 0.9 random_state 68
# accuracy 0.85625 random_state 69
# accuracy 0.896875 random_state 70
# accuracy 0.88125 random_state 71
# accuracy 0.853125 random_state 72
# accuracy 0.915625 random_state 73
# accuracy 0.890625 random_state 74
# accuracy 0.871875 random_state 75
# accuracy 0.853125 random_state 76
# accuracy 0.884375 random_state 77
# accuracy 0.85625 random_state 78
# accuracy 0.834375 random_state 79
# accuracy 0.890625 random_state 80
# accuracy 0.865625 random_state 81
# accuracy 0.89375 random_state 82
# accuracy 0.865625 random_state 83
# accuracy 0.884375 random_state 84
# accuracy 0.875 random_state 85
# accuracy 0.909375 random_state 86
# accuracy 0.915625 random_state 87
# accuracy 0.8875 random_state 88
# accuracy 0.85625 random_state 89
# accuracy 0.88125 random_state 90
# accuracy 0.86875 random_state 91
# accuracy 0.9125 random_state 92
# accuracy 0.8875 random_state 93
# accuracy 0.890625 random_state 94
# accuracy 0.859375 random_state 95
# accuracy 0.88125 random_state 96
# accuracy 0.884375 random_state 97
# accuracy 0.85625 random_state 98
# accuracy 0.8875 random_state 99
# accuracy 0.890625 random_state 100
# accuracy 0.859375 random_state 101
# accuracy 0.86875 random_state 102
# accuracy 0.8875 random_state 103
# accuracy 0.865625 random_state 104
# accuracy 0.875 random_state 105
# accuracy 0.865625 random_state 106
# accuracy 0.890625 random_state 107
# accuracy 0.89375 random_state 108
# accuracy 0.884375 random_state 109
# accuracy 0.890625 random_state 110
# accuracy 0.86875 random_state 111
# accuracy 0.890625 random_state 112
# accuracy 0.878125 random_state 113
# accuracy 0.8875 random_state 114
# accuracy 0.88125 random_state 115
# accuracy 0.878125 random_state 116
# accuracy 0.840625 random_state 117
# accuracy 0.875 random_state 118
# accuracy 0.890625 random_state 119
# accuracy 0.8625 random_state 120
# accuracy 0.88125 random_state 121
# accuracy 0.8875 random_state 122
# accuracy 0.865625 random_state 123
# accuracy 0.878125 random_state 124
# accuracy 0.8625 random_state 125
# accuracy 0.865625 random_state 126
# accuracy 0.896875 random_state 127
# accuracy 0.865625 random_state 128
# accuracy 0.86875 random_state 129
# accuracy 0.88125 random_state 130
# accuracy 0.884375 random_state 131
# accuracy 0.884375 random_state 132
# accuracy 0.8625 random_state 133
# accuracy 0.88125 random_state 134
# accuracy 0.86875 random_state 135
# accuracy 0.896875 random_state 136
# accuracy 0.89375 random_state 137
# accuracy 0.878125 random_state 138
# accuracy 0.8875 random_state 139
# accuracy 0.8875 random_state 140
# accuracy 0.89375 random_state 141
# accuracy 0.871875 random_state 142
# accuracy 0.875 random_state 143
# accuracy 0.859375 random_state 144
# accuracy 0.865625 random_state 145
# accuracy 0.859375 random_state 146
# accuracy 0.878125 random_state 147
# accuracy 0.88125 random_state 148
# accuracy 0.890625 random_state 149
# accuracy 0.871875 random_state 150
# accuracy 0.88125 random_state 151
# accuracy 0.878125 random_state 152
# accuracy 0.871875 random_state 153
# accuracy 0.8625 random_state 154
# accuracy 0.896875 random_state 155
# accuracy 0.85625 random_state 156
# accuracy 0.853125 random_state 157
# accuracy 0.875 random_state 158
# accuracy 0.86875 random_state 159
# accuracy 0.896875 random_state 160
# accuracy 0.890625 random_state 161
# accuracy 0.88125 random_state 162
# accuracy 0.890625 random_state 163
# accuracy 0.840625 random_state 164
# accuracy 0.871875 random_state 165
# accuracy 0.865625 random_state 166
# accuracy 0.8875 random_state 167
# accuracy 0.871875 random_state 168
# accuracy 0.846875 random_state 169
# accuracy 0.88125 random_state 170
# accuracy 0.884375 random_state 171
# accuracy 0.884375 random_state 172
# accuracy 0.88125 random_state 173
# accuracy 0.884375 random_state 174
# accuracy 0.903125 random_state 175
# accuracy 0.91875 random_state 176
# accuracy 0.884375 random_state 177
# accuracy 0.8625 random_state 178
# accuracy 0.890625 random_state 179
# accuracy 0.89375 random_state 180
# accuracy 0.875 random_state 181
# accuracy 0.88125 random_state 182
# accuracy 0.8625 random_state 183
# accuracy 0.846875 random_state 184
# accuracy 0.871875 random_state 185
# accuracy 0.903125 random_state 186
# accuracy 0.896875 random_state 187
# accuracy 0.878125 random_state 188
# accuracy 0.8625 random_state 189
# accuracy 0.88125 random_state 190
# accuracy 0.859375 random_state 191
# accuracy 0.884375 random_state 192
# accuracy 0.890625 random_state 193
# accuracy 0.85625 random_state 194
# accuracy 0.9 random_state 195
# accuracy 0.896875 random_state 196
# accuracy 0.884375 random_state 197
# accuracy 0.8625 random_state 198
# accuracy 0.884375 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.91875 On Random_state  176

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = .20, random_state = i)
    dtc = DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred = dtc.predict(x_test)
    acc = accuracy_score(y_test, pred)
    print('accuracy',acc,'random_state',i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
# Out:
# accuracy 0.890625 random_state 1
# accuracy 0.88125 random_state 2
# accuracy 0.903125 random_state 3
# accuracy 0.903125 random_state 4
# accuracy 0.9 random_state 5
# accuracy 0.896875 random_state 6
# accuracy 0.840625 random_state 7
# accuracy 0.890625 random_state 8
# accuracy 0.91875 random_state 9
# accuracy 0.85 random_state 10
# accuracy 0.896875 random_state 11
# accuracy 0.871875 random_state 12
# accuracy 0.878125 random_state 13
# accuracy 0.865625 random_state 14
# accuracy 0.88125 random_state 15
# accuracy 0.88125 random_state 16
# accuracy 0.88125 random_state 17
# accuracy 0.875 random_state 18
# accuracy 0.909375 random_state 19
# accuracy 0.85 random_state 20
# accuracy 0.884375 random_state 21
# accuracy 0.878125 random_state 22
# accuracy 0.878125 random_state 23
# accuracy 0.853125 random_state 24
# accuracy 0.89375 random_state 25
# accuracy 0.9125 random_state 26
# accuracy 0.878125 random_state 27
# accuracy 0.88125 random_state 28
# accuracy 0.878125 random_state 29
# accuracy 0.884375 random_state 30
# accuracy 0.85 random_state 31
# accuracy 0.88125 random_state 32
# accuracy 0.878125 random_state 33
# accuracy 0.85625 random_state 34
# accuracy 0.8875 random_state 35
# accuracy 0.8375 random_state 36
# accuracy 0.9 random_state 37
# accuracy 0.903125 random_state 38
# accuracy 0.871875 random_state 39
# accuracy 0.871875 random_state 40
# accuracy 0.890625 random_state 41
# accuracy 0.890625 random_state 42
# accuracy 0.871875 random_state 43
# accuracy 0.871875 random_state 44
# accuracy 0.859375 random_state 45
# accuracy 0.84375 random_state 46
# accuracy 0.8625 random_state 47
# accuracy 0.875 random_state 48
# accuracy 0.8625 random_state 49
# accuracy 0.921875 random_state 50
# accuracy 0.90625 random_state 51
# accuracy 0.875 random_state 52
# accuracy 0.85625 random_state 53
# accuracy 0.903125 random_state 54
# accuracy 0.86875 random_state 55
# accuracy 0.865625 random_state 56
# accuracy 0.89375 random_state 57
# accuracy 0.884375 random_state 58
# accuracy 0.91875 random_state 59
# accuracy 0.86875 random_state 60
# accuracy 0.896875 random_state 61
# accuracy 0.88125 random_state 62
# accuracy 0.8875 random_state 63
# accuracy 0.871875 random_state 64
# accuracy 0.90625 random_state 65
# accuracy 0.875 random_state 66
# accuracy 0.9 random_state 67
# accuracy 0.88125 random_state 68
# accuracy 0.871875 random_state 69
# accuracy 0.878125 random_state 70
# accuracy 0.853125 random_state 71
# accuracy 0.90625 random_state 72
# accuracy 0.88125 random_state 73
# accuracy 0.878125 random_state 74
# accuracy 0.859375 random_state 75
# accuracy 0.853125 random_state 76
# accuracy 0.878125 random_state 77
# accuracy 0.921875 random_state 78
# accuracy 0.846875 random_state 79
# accuracy 0.878125 random_state 80
# accuracy 0.89375 random_state 81
# accuracy 0.86875 random_state 82
# accuracy 0.884375 random_state 83
# accuracy 0.9 random_state 84
# accuracy 0.853125 random_state 85
# accuracy 0.90625 random_state 86
# accuracy 0.8875 random_state 87
# accuracy 0.903125 random_state 88
# accuracy 0.878125 random_state 89
# accuracy 0.890625 random_state 90
# accuracy 0.875 random_state 91
# accuracy 0.896875 random_state 92
# accuracy 0.88125 random_state 93
# accuracy 0.909375 random_state 94
# accuracy 0.871875 random_state 95
# accuracy 0.89375 random_state 96
# accuracy 0.896875 random_state 97
# accuracy 0.865625 random_state 98
# accuracy 0.8875 random_state 99
# accuracy 0.89375 random_state 100
# accuracy 0.86875 random_state 101
# accuracy 0.871875 random_state 102
# accuracy 0.875 random_state 103
# accuracy 0.871875 random_state 104
# accuracy 0.878125 random_state 105
# accuracy 0.865625 random_state 106
# accuracy 0.884375 random_state 107
# accuracy 0.896875 random_state 108
# accuracy 0.846875 random_state 109
# accuracy 0.8625 random_state 110
# accuracy 0.890625 random_state 111
# accuracy 0.88125 random_state 112
# accuracy 0.878125 random_state 113
# accuracy 0.875 random_state 114
# accuracy 0.91875 random_state 115
# accuracy 0.878125 random_state 116
# accuracy 0.84375 random_state 117
# accuracy 0.88125 random_state 118
# accuracy 0.865625 random_state 119
# accuracy 0.85625 random_state 120
# accuracy 0.9 random_state 121
# accuracy 0.88125 random_state 122
# accuracy 0.875 random_state 123
# accuracy 0.878125 random_state 124
# accuracy 0.878125 random_state 125
# accuracy 0.878125 random_state 126
# accuracy 0.89375 random_state 127
# accuracy 0.8875 random_state 128
# accuracy 0.875 random_state 129
# accuracy 0.865625 random_state 130
# accuracy 0.884375 random_state 131
# accuracy 0.8875 random_state 132
# accuracy 0.859375 random_state 133
# accuracy 0.890625 random_state 134
# accuracy 0.890625 random_state 135
# accuracy 0.88125 random_state 136
# accuracy 0.878125 random_state 137
# accuracy 0.840625 random_state 138
# accuracy 0.878125 random_state 139
# accuracy 0.875 random_state 140
# accuracy 0.871875 random_state 141
# accuracy 0.884375 random_state 142
# accuracy 0.9 random_state 143
# accuracy 0.840625 random_state 144
# accuracy 0.884375 random_state 145
# accuracy 0.896875 random_state 146
# accuracy 0.871875 random_state 147
# accuracy 0.878125 random_state 148
# accuracy 0.821875 random_state 149
# accuracy 0.859375 random_state 150
# accuracy 0.8625 random_state 151
# accuracy 0.89375 random_state 152
# accuracy 0.896875 random_state 153
# accuracy 0.884375 random_state 154
# accuracy 0.865625 random_state 155
# accuracy 0.825 random_state 156
# accuracy 0.865625 random_state 157
# accuracy 0.89375 random_state 158
# accuracy 0.853125 random_state 159
# accuracy 0.875 random_state 160
# accuracy 0.871875 random_state 161
# accuracy 0.8625 random_state 162
# accuracy 0.89375 random_state 163
# accuracy 0.871875 random_state 164
# accuracy 0.884375 random_state 165
# accuracy 0.88125 random_state 166
# accuracy 0.84375 random_state 167
# accuracy 0.865625 random_state 168
# accuracy 0.890625 random_state 169
# accuracy 0.865625 random_state 170
# accuracy 0.884375 random_state 171
# accuracy 0.875 random_state 172
# accuracy 0.86875 random_state 173
# accuracy 0.884375 random_state 174
# accuracy 0.90625 random_state 175
# accuracy 0.9125 random_state 176
# accuracy 0.8875 random_state 177
# accuracy 0.875 random_state 178
# accuracy 0.90625 random_state 179
# accuracy 0.884375 random_state 180
# accuracy 0.875 random_state 181
# accuracy 0.85625 random_state 182
# accuracy 0.85625 random_state 183
# accuracy 0.828125 random_state 184
# accuracy 0.86875 random_state 185
# accuracy 0.8625 random_state 186
# accuracy 0.890625 random_state 187
# accuracy 0.9 random_state 188
# accuracy 0.896875 random_state 189
# accuracy 0.859375 random_state 190
# accuracy 0.871875 random_state 191
# accuracy 0.8875 random_state 192
# accuracy 0.890625 random_state 193
# accuracy 0.890625 random_state 194
# accuracy 0.89375 random_state 195
# accuracy 0.88125 random_state 196
# accuracy 0.8875 random_state 197
# accuracy 0.840625 random_state 198
# accuracy 0.8875 random_state 199

# %%
print("Best accuracy is ",maxAccu,"On Random_state ",maxRS)
# Out:
# Best accuracy is  0.91875 On Random_state  176

# %% [markdown]
# # Creating train-test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.20,random_state = 50)

# %%
x_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1147           10.0             0.410         0.45             6.2      0.071
# 1267           10.4             0.430         0.50             2.3      0.068
# 605             8.3             0.600         0.13             2.6      0.085
# 1408            8.1             0.290         0.36             2.2      0.048
# 1025            8.6             0.830         0.00             2.8      0.095
# ...             ...               ...          ...             ...        ...
# 70              7.7             0.630         0.08             1.9      0.076
# 132             5.6             0.500         0.09             2.3      0.049
# 1313            7.0             0.360         0.21             2.3      0.086
# 109             8.1             0.785         0.52             2.0      0.122
# 1504            7.5             0.380         0.57             2.3      0.106
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1147                  6.0                  14.0  0.99702  3.21       0.49
# 1267                 13.0                  19.0  0.99600  3.10       0.87
# 605                   6.0                  24.0  0.99840  3.31       0.59
# 1408                 35.0                  53.0  0.99500  3.27       1.01
# 1025                 17.0                  43.0  0.99822  3.33       0.60
# ...                   ...                   ...      ...   ...        ...
# 70                   15.0                  27.0  0.99670  3.32       0.54
# 132                  17.0                  99.0  0.99370  3.63       0.63
# 1313                 20.0                  65.0  0.99558  3.40       0.54
# 109                  37.0                 153.0  0.99690  3.21       0.69
# 1504                  5.0                  12.0  0.99605  3.36       0.55
#
#       alcohol
# 1147     11.8
# 1267     11.4
# 605       9.2
# 1408     12.4
# 1025     10.4
# ...       ...
# 70        9.5
# 132      13.0
# 1313     10.1
# 109       9.3
# 1504     11.4
#
# [1279 rows x 11 columns]

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 453            10.4             0.330         0.63             2.8      0.084
# 1415            6.2             0.580         0.00             1.6      0.065
# 1242            9.0             0.400         0.41             2.0      0.058
# 885             8.9             0.750         0.14             2.5      0.086
# 488            11.6             0.320         0.55             2.8      0.081
# ...             ...               ...          ...             ...        ...
# 160             7.6             0.950         0.03             2.0      0.090
# 532            11.9             0.380         0.49             2.7      0.098
# 1515            6.9             0.840         0.21             4.1      0.074
# 257             6.6             0.695         0.00             2.1      0.075
# 697             7.0             0.650         0.02             2.1      0.066
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 453                   5.0                  22.0  0.99980  3.26       0.74
# 1415                  8.0                  18.0  0.99660  3.56       0.84
# 1242                 15.0                  40.0  0.99414  3.22       0.60
# 885                   9.0                  30.0  0.99824  3.34       0.64
# 488                  35.0                  67.0  1.00020  3.32       0.92
# ...                   ...                   ...      ...   ...        ...
# 160                   7.0                  20.0  0.99590  3.20       0.56
# 532                  12.0                  42.0  1.00040  3.16       0.61
# 1515                 16.0                  65.0  0.99842  3.53       0.72
# 257                  12.0                  56.0  0.99680  3.49       0.67
# 697                   8.0                  25.0  0.99720  3.47       0.67
#
#       alcohol
# 453     11.20
# 1415     9.40
# 1242    12.20
# 885     10.50
# 488     10.80
# ...       ...
# 160      9.60
# 532     10.30
# 1515     9.25
# 257      9.20
# 697      9.50
#
# [320 rows x 11 columns]

# %%
y_train
# Out:
# 1147    1
# 1267    0
# 605     0
# 1408    1
# 1025    0
#        ..
# 70      0
# 132     0
# 1313    0
# 109     0
# 1504    0
# Name: quality, Length: 1279, dtype: int64

# %%
y_test
# Out:
# 453     1
# 1415    0
# 1242    0
# 885     0
# 488     1
#        ..
# 160     0
# 532     0
# 1515    0
# 257     0
# 697     0
# Name: quality, Length: 320, dtype: int64

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (1599, 11) (1279, 11) (320, 11)

# %%
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (1599,) (1279,) (320,)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
pred = rfc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 95.9375
# [[284   3]
#  [ 10  23]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       287
#            1       0.88      0.70      0.78        33
#
#     accuracy                           0.96       320
#    macro avg       0.93      0.84      0.88       320
# weighted avg       0.96      0.96      0.96       320

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 92.1875
# [[274  13]
#  [ 12  21]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       287
#            1       0.62      0.64      0.63        33
#
#     accuracy                           0.92       320
#    macro avg       0.79      0.80      0.79       320
# weighted avg       0.92      0.92      0.92       320

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train,y_train)
pred = svc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 90.0
# [[287   0]
#  [ 32   1]]
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       287
#            1       1.00      0.03      0.06        33
#
#     accuracy                           0.90       320
#    macro avg       0.95      0.52      0.50       320
# weighted avg       0.91      0.90      0.86       320

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 91.5625
# [[283   4]
#  [ 23  10]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       287
#            1       0.71      0.30      0.43        33
#
#     accuracy                           0.92       320
#    macro avg       0.82      0.64      0.69       320
# weighted avg       0.90      0.92      0.90       320

# %% [markdown]
# # XGBClassifier

# %%
from xgboost import XGBClassifier
xc = XGBClassifier()
xc.fit(x_train,y_train)
pred = xc.predict(x_test)
print('accuracy',accuracy_score(y_test, pred)*100)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy 95.0
# [[282   5]
#  [ 11  22]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       287
#            1       0.81      0.67      0.73        33
#
#     accuracy                           0.95       320
#    macro avg       0.89      0.82      0.85       320
# weighted avg       0.95      0.95      0.95       320

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

scr = cross_val_score(rfc, x, y, cv=5)
print('cross validation score of random forest classifier model :',scr.mean())
# Out:
# cross validation score of random forest classifier model : 0.8724196708463949

# %%
scr2 = cross_val_score(lr, x, y, cv=5)
print('cross validation score of logistic regression model :',scr2.mean())
# Out:
# cross validation score of logistic regression model : 0.868044670846395

# %%
scr3 = cross_val_score(dtc, x, y, cv=5)
print('cross validation score of decision tree classifier model :',scr3.mean())
# Out:
# cross validation score of decision tree classifier model : 0.8029956896551724

# %%
scr4 = cross_val_score(svc, x, y, cv=5)
print('cross validation score of support vector classifier model :',scr4.mean())
# Out:
# cross validation score of support vector classifier model : 0.8642907523510971

# %%
scr5 = cross_val_score(svc, x, y, cv=5)
print('cross validation score of xg boost classifier model :',scr5.mean())
# Out:
# cross validation score of xg boost classifier model : 0.8642907523510971

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'max_features': ['auto','sqrt','log2'],
              'max_depth': [4,5,6,7,8],
              'criterion':['gini','entropy']}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2'}

# %%
type(GCV)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(max_depth=8, max_features='log2')

# %%
GCV_pred = GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.95

# %% [markdown]
# # ROC AUC plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC Plot")
plt.show()

# %% [markdown]
# Final accuracy is 95% and AUC score is 98% which is pretty good

# %% [markdown]
# # Saving the model in pickle format

# %%
#import joblib
#joblib.dump(GCV.best_estimator_,'')
