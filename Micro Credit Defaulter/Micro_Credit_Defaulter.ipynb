# %% [markdown]
# # Data Reading and Analysis:

# %%
# Importing libraries.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset.
import pandas as pd
df = pd.read_csv(r'C:/Users/dipak/Desktop/Micro Credit Project/micro_credit.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0         220.13    260.13                2.0                0.0  ...
# 1        3691.26   3691.26               20.0                0.0  ...
# 2         900.13    900.13                3.0                0.0  ...
# 3         159.42    159.42               41.0                0.0  ...
# 4        1098.90   1098.90                4.0                0.0  ...
# ...          ...       ...                ...                ...  ...
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                     6                 0.0  29.000000  29.000000      UPW
# 1                    12                 0.0   0.000000   0.000000      UPW
# 2                     6                 0.0   0.000000   0.000000      UPW
# 3                     6                 0.0   0.000000   0.000000      UPW
# 4                     6                 0.0   2.333333   2.333333      UPW
# ...                 ...                 ...        ...        ...      ...
# 209588                6                 0.0   1.000000   1.000000      UPW
# 209589                6                 0.0   1.000000   1.000000      UPW
# 209590               12                 0.0   4.000000   3.833333      UPW
# 209591               12                 0.0   0.000000  10.500000      UPW
# 209592               12                 0.0   0.000000   0.000000      UPW
#
#              pdate
# 0       2016-07-20
# 1       2016-08-10
# 2       2016-08-19
# 3       2016-06-06
# 4       2016-06-22
# ...            ...
# 209588  2016-06-17
# 209589  2016-06-12
# 209590  2016-07-29
# 209591  2016-07-25
# 209592  2016-07-07
#
# [209593 rows x 37 columns]

# %%
# drop unnamed column
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                6                 0.0  29.000000  29.000000      UPW
# 1               12                 0.0   0.000000   0.000000      UPW
# 2                6                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   2.333333   2.333333      UPW
#
#         pdate
# 0  2016-07-20
# 1  2016-08-10
# 2  2016-08-19
# 3  2016-06-06
# 4  2016-06-22
#
# [5 rows x 36 columns]

# %%
# Get the numbers of rows and columns.
df.shape
# Out:
# (209593, 36)

# %%
# Check column of the dataframe.
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# Get the column datatypes.
df.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# dtype: object

# %%
# Basic information about dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
#  14  medianmarechprebal30  209593 non-null  float64
#  15  cnt_ma_rech90         209593 non-null  int64
#  16  fr_ma_rech90          209593 non-null  int64
#  17  sumamnt_ma_rech90     209593 non-null  int64
#  18  medianamnt_ma_rech90  209593 non-null  float64
#  19  medianmarechprebal90  209593 non-null  float64
#  20  cnt_da_rech30         209593 non-null  float64
#  21  fr_da_rech30          209593 non-null  float64
#  22  cnt_da_rech90         209593 non-null  int64
#  23  fr_da_rech90          209593 non-null  int64
#  24  cnt_loans30           209593 non-null  int64
#  25  amnt_loans30          209593 non-null  int64
#  26  maxamnt_loans30       209593 non-null  float64
#  27  medianamnt_loans30    209593 non-null  float64
#  28  cnt_loans90           209593 non-null  float64
#  29  amnt_loans90          209593 non-null  int64
#  30  maxamnt_loans90       209593 non-null  int64
#  31  medianamnt_loans90    209593 non-null  float64
#  32  payback30             209593 non-null  float64
#  33  payback90             209593 non-null  float64
#  34  pcircle               209593 non-null  object
#  35  pdate                 209593 non-null  object
# dtypes: float64(21), int64(12), object(3)
# memory usage: 57.6+ MB

# %%
# Get a count of the empty values for each column.
df.isna().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
# Check any missing/null values in the dataset.
df.isnull().values.any()
# Out:
# False

# %%
# Checking for null values using heatmap.
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Get the number of unique values.
df.nunique()
# Out:
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# amnt_loans90                69
# maxamnt_loans90              3
# medianamnt_loans90           6
# payback30                 1363
# payback90                 2381
# pcircle                      1
# pdate                       82
# dtype: int64

# %% [markdown]
# # Data Preprocessing:

# %% [markdown]
# ### Remove columns where number of unique value is only 1.

# %%
unique = df.nunique()
unique = unique[unique.values == 1]
unique
# Out:
# pcircle    1
# dtype: int64

# %%
df.drop('pcircle', axis=1, inplace=True)
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  amnt_loans30  \
# 0                2.0                0.0              1539  ...            12
# 1               20.0                0.0              5787  ...            12
# 2                3.0                0.0              1539  ...             6
# 3               41.0                0.0               947  ...            12
# 4                4.0                0.0              2309  ...            42
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90       pdate
# 0                6                 0.0  29.000000  29.000000  2016-07-20
# 1               12                 0.0   0.000000   0.000000  2016-08-10
# 2                6                 0.0   0.000000   0.000000  2016-08-19
# 3                6                 0.0   0.000000   0.000000  2016-06-06
# 4                6                 0.0   2.333333   2.333333  2016-06-22
#
# [5 rows x 35 columns]

# %%
# Summary statistics.
df.describe().transpose().style.background_gradient()
# Out:
# <style type="text/css">
# #T_88bab_row0_col0, #T_88bab_row0_col1, #T_88bab_row0_col2, #T_88bab_row0_col4, #T_88bab_row0_col5, #T_88bab_row0_col6, #T_88bab_row0_col7, #T_88bab_row1_col0, #T_88bab_row2_col0, #T_88bab_row3_col0, #T_88bab_row4_col0, #T_88bab_row5_col0, #T_88bab_row5_col3, #T_88bab_row6_col0, #T_88bab_row6_col4, #T_88bab_row6_col5, #T_88bab_row6_col6, #T_88bab_row7_col0, #T_88bab_row7_col4, #T_88bab_row7_col5, #T_88bab_row7_col6, #T_88bab_row8_col0, #T_88bab_row9_col0, #T_88bab_row9_col1, #T_88bab_row9_col2, #T_88bab_row9_col4, #T_88bab_row9_col5, #T_88bab_row9_col6, #T_88bab_row9_col7, #T_88bab_row10_col0, #T_88bab_row10_col4, #T_88bab_row10_col5, #T_88bab_row10_col6, #T_88bab_row11_col0, #T_88bab_row12_col0, #T_88bab_row13_col0, #T_88bab_row14_col0, #T_88bab_row14_col1, #T_88bab_row14_col2, #T_88bab_row14_col4, #T_88bab_row14_col5, #T_88bab_row14_col6, #T_88bab_row14_col7, #T_88bab_row15_col0, #T_88bab_row15_col1, #T_88bab_row15_col2, #T_88bab_row15_col4, #T_88bab_row15_col5, #T_88bab_row15_col6, #T_88bab_row15_col7, #T_88bab_row16_col0, #T_88bab_row17_col0, #T_88bab_row18_col0, #T_88bab_row19_col0, #T_88bab_row19_col4, #T_88bab_row19_col5, #T_88bab_row19_col6, #T_88bab_row20_col0, #T_88bab_row20_col4, #T_88bab_row20_col5, #T_88bab_row20_col6, #T_88bab_row21_col0, #T_88bab_row21_col1, #T_88bab_row21_col2, #T_88bab_row21_col4, #T_88bab_row21_col5, #T_88bab_row21_col6, #T_88bab_row21_col7, #T_88bab_row22_col0, #T_88bab_row22_col1, #T_88bab_row22_col2, #T_88bab_row22_col4, #T_88bab_row22_col5, #T_88bab_row22_col6, #T_88bab_row22_col7, #T_88bab_row23_col0, #T_88bab_row23_col1, #T_88bab_row23_col2, #T_88bab_row23_col4, #T_88bab_row23_col5, #T_88bab_row23_col6, #T_88bab_row23_col7, #T_88bab_row24_col0, #T_88bab_row24_col1, #T_88bab_row24_col2, #T_88bab_row24_col4, #T_88bab_row24_col5, #T_88bab_row24_col6, #T_88bab_row24_col7, #T_88bab_row25_col0, #T_88bab_row25_col4, #T_88bab_row25_col5, #T_88bab_row25_col6, #T_88bab_row26_col0, #T_88bab_row26_col1, #T_88bab_row26_col2, #T_88bab_row26_col4, #T_88bab_row26_col5, #T_88bab_row26_col6, #T_88bab_row26_col7, #T_88bab_row27_col0, #T_88bab_row27_col1, #T_88bab_row27_col2, #T_88bab_row27_col4, #T_88bab_row27_col5, #T_88bab_row27_col6, #T_88bab_row28_col0, #T_88bab_row28_col1, #T_88bab_row28_col2, #T_88bab_row28_col4, #T_88bab_row28_col5, #T_88bab_row28_col6, #T_88bab_row28_col7, #T_88bab_row29_col0, #T_88bab_row29_col1, #T_88bab_row29_col2, #T_88bab_row29_col4, #T_88bab_row29_col5, #T_88bab_row29_col6, #T_88bab_row29_col7, #T_88bab_row30_col0, #T_88bab_row30_col1, #T_88bab_row30_col2, #T_88bab_row30_col4, #T_88bab_row30_col5, #T_88bab_row30_col6, #T_88bab_row30_col7, #T_88bab_row31_col0, #T_88bab_row31_col1, #T_88bab_row31_col2, #T_88bab_row31_col4, #T_88bab_row31_col5, #T_88bab_row31_col6, #T_88bab_row31_col7, #T_88bab_row32_col0, #T_88bab_row32_col1, #T_88bab_row32_col2, #T_88bab_row32_col4, #T_88bab_row32_col5, #T_88bab_row32_col6, #T_88bab_row32_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_88bab_row0_col3, #T_88bab_row1_col2, #T_88bab_row1_col3, #T_88bab_row1_col7, #T_88bab_row2_col3, #T_88bab_row3_col3, #T_88bab_row6_col3, #T_88bab_row6_col7, #T_88bab_row7_col3, #T_88bab_row7_col7, #T_88bab_row8_col3, #T_88bab_row9_col3, #T_88bab_row10_col3, #T_88bab_row10_col7, #T_88bab_row11_col3, #T_88bab_row12_col3, #T_88bab_row13_col7, #T_88bab_row14_col3, #T_88bab_row15_col3, #T_88bab_row16_col1, #T_88bab_row16_col3, #T_88bab_row16_col4, #T_88bab_row16_col5, #T_88bab_row16_col6, #T_88bab_row17_col3, #T_88bab_row19_col3, #T_88bab_row20_col3, #T_88bab_row20_col7, #T_88bab_row21_col3, #T_88bab_row22_col3, #T_88bab_row23_col3, #T_88bab_row24_col3, #T_88bab_row25_col3, #T_88bab_row26_col3, #T_88bab_row27_col3, #T_88bab_row28_col3, #T_88bab_row29_col3, #T_88bab_row30_col3, #T_88bab_row31_col3, #T_88bab_row32_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_88bab_row1_col1 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_88bab_row1_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_88bab_row1_col5 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_88bab_row1_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_88bab_row2_col1 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_88bab_row2_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_88bab_row2_col4, #T_88bab_row3_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_88bab_row2_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_88bab_row2_col6 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_88bab_row2_col7 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_88bab_row3_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_88bab_row3_col2, #T_88bab_row8_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_88bab_row3_col5, #T_88bab_row4_col6, #T_88bab_row8_col5, #T_88bab_row12_col5, #T_88bab_row17_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_88bab_row3_col6 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_88bab_row3_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_88bab_row4_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_88bab_row4_col2, #T_88bab_row8_col7, #T_88bab_row12_col7, #T_88bab_row17_col7, #T_88bab_row19_col2, #T_88bab_row25_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_88bab_row4_col3, #T_88bab_row18_col7 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_88bab_row4_col4, #T_88bab_row12_col6, #T_88bab_row17_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_88bab_row4_col5, #T_88bab_row12_col1, #T_88bab_row17_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_88bab_row4_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_88bab_row5_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_88bab_row5_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_88bab_row5_col4 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_88bab_row5_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_88bab_row5_col6 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_88bab_row5_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_88bab_row6_col1, #T_88bab_row10_col1, #T_88bab_row20_col1 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_88bab_row6_col2, #T_88bab_row13_col2, #T_88bab_row20_col2 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_88bab_row7_col1 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_88bab_row7_col2 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_88bab_row8_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_88bab_row8_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_88bab_row8_col4, #T_88bab_row12_col4, #T_88bab_row17_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_88bab_row10_col2 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_88bab_row11_col1 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_88bab_row11_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_88bab_row11_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_88bab_row11_col5 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_88bab_row11_col6 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_88bab_row11_col7 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_88bab_row12_col2, #T_88bab_row17_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_88bab_row13_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_88bab_row13_col3, #T_88bab_row18_col3 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_88bab_row13_col4, #T_88bab_row13_col5, #T_88bab_row13_col6, #T_88bab_row18_col1, #T_88bab_row18_col2, #T_88bab_row18_col4, #T_88bab_row18_col5, #T_88bab_row18_col6, #T_88bab_row27_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_88bab_row16_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_88bab_row16_col7 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_88bab_row19_col1, #T_88bab_row25_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_88bab_row19_col7, #T_88bab_row25_col7 {
#   backgroun

# %%
# Summary statistics for object and datetime.
df.describe(include=['object','datetime']).transpose()
# Out:
#          count  unique          top  freq
# msisdn  209593  186243  04581I85330     7
# pdate   209593      82   2016-07-04  3150

# %%
df1 = df.copy()

# %%
# Drop duplicate values of msisdn column.
df.drop_duplicates(subset='msisdn',keep='first',inplace=True)
df.shape
# Out:
# (186243, 35)

# %% [markdown]
# # Data Exploration:

# %%
# Print all of the data types and their unique values.
for column in df.columns:
    if df[column].dtype == object:
        print(str(column) + ' : ' + str(df[column].unique()))
        print(df[column].value_counts())
        print('____________________________________________')
# Out:
# msisdn : ['21408I70789' '76462I70374' '17943I70372' ... '22758I85348' '59712I82733'
#  '65061I85339']
# 21408I70789    1
# 77953I95203    1
# 37896I85348    1
# 49727I70372    1
# 08288I88649    1
#               ..
# 74074I82731    1
# 04445I85349    1
# 09031I70378    1
# 88188I90580    1
# 65061I85339    1
# Name: msisdn, Length: 186243, dtype: int64
# ____________________________________________
# pdate : ['2016-07-20' '2016-08-10' '2016-08-19' '2016-06-06' '2016-06-22'
#  '2016-07-02' '2016-07-05' '2016-08-05' '2016-06-15' '2016-06-08'
#  '2016-06-12' '2016-06-20' '2016-06-29' '2016-06-16' '2016-08-03'
#  '2016-06-24' '2016-07-04' '2016-07-03' '2016-07-01' '2016-08-08'
#  '2016-06-26' '2016-06-23' '2016-07-06' '2016-07-09' '2016-06-10'
#  '2016-06-07' '2016-06-27' '2016-08-11' '2016-06-30' '2016-06-19'
#  '2016-07-26' '2016-08-14' '2016-06-14' '2016-06-21' '2016-06-25'
#  '2016-06-28' '2016-06-11' '2016-07-27' '2016-07-23' '2016-08-16'
#  '2016-08-15' '2016-06-02' '2016-06-05' '2016-08-02' '2016-07-28'
#  '2016-07-18' '2016-08-18' '2016-07-16' '2016-07-29' '2016-07-21'
#  '2016-06-03' '2016-06-13' '2016-08-01' '2016-07-13' '2016-07-10'
#  '2016-06-09' '2016-07-15' '2016-07-11' '2016-08-09' '2016-08-12'
#  '2016-07-22' '2016-06-04' '2016-07-24' '2016-06-18' '2016-08-13'
#  '2016-06-17' '2016-08-07' '2016-07-12' '2016-08-06' '2016-07-19'
#  '2016-08-21' '2016-08-04' '2016-07-25' '2016-07-30' '2016-08-17'
#  '2016-07-08' '2016-07-14' '2016-06-01' '2016-07-07' '2016-07-17'
#  '2016-07-31' '2016-08-20']
# 2016-07-05    2825
# 2016-07-07    2792
# 2016-07-04    2790
# 2016-06-20    2785
# 2016-06-17    2770
#               ...
# 2016-06-04    1395
# 2016-08-18    1226
# 2016-08-19     970
# 2016-08-20     675
# 2016-08-21     276
# Name: pdate, Length: 82, dtype: int64
# ____________________________________________

# %%
# Print all of the data types and their unique values.
for column in df.columns:
    if df[column].dtype == np.number:
        print(str(column) + ' : ' + str(df[column].nunique()))
        print(df[column].value_counts())
        print('____________________________________________')
# Out:
# aon : 4282
# 95.000000        366
# 92.000000        342
# 96.000000        339
# 99.000000        335
# 94.000000        328
#                 ...
# 847385.682864      1
# 602000.328014      1
# 825740.918634      1
# 654148.566653      1
# 581435.484230      1
# Name: aon, Length: 4282, dtype: int64
# ____________________________________________
# daily_decr30 : 130323
# 0.000000       4136
# 500.000000      823
# 1000.000000     557
# 700.000000      377
# 600.000000      347
#                ...
# 7649.996000       1
# 133.739000        1
# 21.924000         1
# 3702.133333       1
# 4489.362000       1
# Name: daily_decr30, Length: 130323, dtype: int64
# ____________________________________________
# daily_decr90 : 139842
# 0.000000       4055
# 500.000000      776
# 1000.000000     482
# 700.000000      339
# 600.000000      309
#                ...
# 1700.300000       1
# 155.725000        1
# 75.226667         1
# 9525.680000       1
# 4534.820000       1
# Name: daily_decr90, Length: 139842, dtype: int64
# ____________________________________________
# rental30 : 117881
# 0.00        7306
# 200.13      1281
# 99.56        961
# 400.26       490
# 199.12       431
#             ...
# 10703.19       1
# 414.21         1
# 10755.85       1
# 5401.55        1
# 483.92         1
# Name: rental30, Length: 117881, dtype: int64
# ____________________________________________
# rental90 : 125595
# 0.00       6664
# 200.13      829
# 99.56       715
# 90.00       670
# 60.00       667
#            ...
# 353.00        1
# 7189.86       1
# 5433.00       1
# 550.08        1
# 984.58        1
# Name: rental90, Length: 125595, dtype: int64
# ____________________________________________
# last_rech_date_ma : 1061
# 1.000000         39931
# 2.000000         22375
# 0.000000         20048
# 3.000000         17071
# 4.000000         13442
#                  ...
# 891201.962251        1
# 861006.563529        1
# 565919.614630        1
# 870737.239835        1
# 590843.121987        1
# Name: last_rech_date_ma, Length: 1061, dtype: int64
# ____________________________________________
# last_rech_date_da : 1061
# 0.000000         180179
# 8.000000            142
# 7.000000            141
# 13.000000           134
# 12.000000           134
#                   ...
# 661517.048953         1
# 743877.315428         1
# 794813.743094         1
# 608243.093593         1
# 799233.445316         1
# Name: last_rech_date_da, Length: 1061, dtype: int64
# ____________________________________________
# fr_ma_rech30 : 961
# 0.000000         73780
# 1.000000         17946
# 2.000000         15438
# 3.000000         12030
# 4.000000          9562
#                  ...
# 812928.243657        1
# 764012.189466        1
# 538982.946775        1
# 974122.601561        1
# 905481.035355        1
# Name: fr_ma_rech30, Length: 961, dtype: int64
# ____________________________________________
# sumamnt_ma_rech30 : 13130
# 0.0        27045
# 1539.0      8543
# 770.0       5802
# 773.0       4316
# 2309.0      4240
#            ...
# 32008.0        1
# 35441.0        1
# 32343.0        1
# 18782.0        1
# 12154.0        1
# Name: sumamnt_ma_rech30, Length: 13130, dtype: int64
# ____________________________________________
# medianamnt_ma_rech30 : 501
# 1539.0     40859
# 0.0        27045
# 770.0      26982
# 773.0      19648
# 2309.0      9584
#            ...
# 7983.5         1
# 2690.5         1
# 4729.5         1
# 4742.0         1
# 10963.5        1
# Name: medianamnt_ma_rech30, Length: 501, dtype: int64
# ____________________________________________
# medianmarechprebal30 : 28486
# 0.00       29575
# 10.00        966
# 20.00        955
# 19.00        944
# 17.00        931
#            ...
# 51.87          1
# 1614.44        1
# 75.90          1
# 386.93         1
# 490.07         1
# Name: medianmarechprebal30, Length: 28486, dtype: int64
# ____________________________________________
# medianamnt_ma_rech90 : 602
# 1539.0     39180
# 773.0      26520
# 770.0      21025
# 0.0        20249
# 2309.0      9158
#            ...
# 477.0          1
# 1985.0         1
# 6797.0         1
# 1526.5         1
# 10963.5        1
# Name: medianamnt_ma_rech90, Length: 602, dtype: int64
# ____________________________________________
# medianmarechprebal90 : 28064
#  0.00      22565
#  20.00      1092
#  19.00      1066
#  26.00      1017
#  10.00      1010
#            ...
#  533.06        1
#  335.95        1
#  60.37         1
# -167.65        1
#  392.20        1
# Name: medianmarechprebal90, Length: 28064, dtype: int64
# ____________________________________________
# cnt_da_rech30 : 949
# 0.000000        182546
# 1.000000          2119
# 2.000000           331
# 3.000000           136
# 4.000000            74
#                  ...
# 93293.175759         1
# 57680.539854         1
# 40229.653638         1
# 38874.292540         1
# 61002.421345         1
# Name: cnt_da_rech30, Length: 949, dtype: int64
# ____________________________________________
# fr_da_rech30 : 960
# 0.000000         184850
# 3.000000             55
# 1.000000             49
# 2.000000             44
# 7.000000             42
#                   ...
# 987737.461692         1
# 919878.156274         1
# 891603.293363         1
# 752906.145644         1
# 744924.810599         1
# Name: fr_da_rech30, Length: 960, dtype: int64
# ____________________________________________
# maxamnt_loans30 : 924
# 6.000000        159569
# 12.000000        22580
# 0.000000          3173
# 30795.349649         1
# 68153.767618         1
#                  ...
# 83352.460538         1
# 31545.936341         1
# 12375.986576         1
# 25213.000065         1
# 96927.243252         1
# Name: maxamnt_loans30, Length: 924, dtype: int64
# ____________________________________________
# medianamnt_loans30 : 6
# 0.0    173264
# 1.0      6633
# 0.5      5908
# 2.0       400
# 1.5        35
# 3.0         3
# Name: medianamnt_loans30, dtype: int64
# ____________________________________________
# cnt_loans90 : 968
# 1.000000       70930
# 2.000000       34429
# 3.000000       21315
# 4.000000       14642
# 5.000000       10355
#                ...
# 4876.239599        1
# 2188.425329        1
# 4576.386262        1
# 3847.122949        1
# 2047.902454        1
# Name: cnt_loans90, Length: 968, dtype: int64
# ____________________________________________
# medianamnt_loans90 : 6
# 0.0    174957
# 1.0      5775
# 0.5      5202
# 2.0       288
# 1.5        18
# 3.0         3
# Name: medianamnt_loans90, dtype: int64
# ____________________________________________
# payback30 : 1249
# 0.000000     101646
# 2.000000       4607
# 3.000000       4095
# 4.000000       3299
# 2.500000       2918
#               ...
# 3.916667          1
# 38.428571         1
# 90.333333         1
# 8.571429          1
# 5.615385          1
# Name: payback30, Length: 1249, dtype: int64
# ____________________________________________
# payback90 : 2128
# 0.000000     91376
# 2.000000      4143
# 3.000000      3682
# 4.000000      3039
# 2.500000      2519
#              ...
# 32.571429        1
# 48.600000        1
# 3.608696         1
# 18.727273        1
# 5.235294         1
# Name: payback90, Length: 2128, dtype: int64
# ____________________________________________

# %%
# Checking the number of defaulter and non-defaulter customer
df['label'].value_counts()
# Out:
# 1    160383
# 0     25860
# Name: label, dtype: int64

# %%
# Checking the number of defaulter and non-defaulter customer percentage wise.
df['label'].value_counts(normalize=True) * 100
# Out:
# 1    86.114914
# 0    13.885086
# Name: label, dtype: float64

# %% [markdown]
# #### Correlation matrix

# %%
# Check correlation of columns.
df.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.004035      0.174901      0.173016
# aon                  -0.004035  1.000000      0.000630      0.000052
# daily_decr30          0.174901  0.000630      1.000000      0.977659
# daily_decr90          0.173016  0.000052      0.977659      1.000000
# rental30              0.057207 -0.002930      0.427503      0.420561
# rental90              0.075869 -0.002618      0.444932      0.457443
# last_rech_date_ma     0.004113  0.001853     -0.000171      0.000058
# last_rech_date_da     0.001814 -0.001796     -0.001311     -0.001484
# last_rech_amt_ma      0.139969  0.004102      0.287181      0.275195
# cnt_ma_rech30         0.244728 -0.004315      0.444365      0.419650
# fr_ma_rech30          0.001129 -0.000436      0.000766      0.001091
# sumamnt_ma_rech30     0.207727 -0.000397      0.630202      0.597542
# medianamnt_ma_rech30  0.149780  0.004446      0.307440      0.294838
# medianmarechprebal30 -0.004835  0.004221     -0.000854     -0.000688
# cnt_ma_rech90         0.245941 -0.003957      0.576787      0.582115
# fr_ma_rech90          0.094709  0.005517     -0.061858     -0.063740
# sumamnt_ma_rech90     0.212666  0.000160      0.754042      0.759865
# medianamnt_ma_rech90  0.129527  0.005022      0.269721      0.262627
# medianmarechprebal90  0.041728 -0.001128      0.042276      0.041210
# cnt_da_rech30         0.004184  0.002445      0.000312     -0.000128
# fr_da_rech30         -0.000137  0.000806     -0.002442     -0.002189
# cnt_da_rech90         0.003601  0.000868      0.038944      0.031408
# fr_da_rech90         -0.005779  0.006379      0.019874      0.015944
# cnt_loans30           0.197565 -0.003157      0.346504      0.321006
# amnt_loans30          0.199916 -0.003302      0.454169      0.430940
# maxamnt_loans30      -0.000274 -0.003096      0.001569      0.001283
# medianamnt_loans30    0.050067  0.004679     -0.005629      0.000012
# cnt_loans90           0.004305  0.000192      0.008865      0.009220
# amnt_loans90          0.205065 -0.003336      0.542179      0.544854
# maxamnt_loans90       0.086033 -0.000975      0.396803      0.394487
# medianamnt_loans90    0.041265  0.002346     -0.031485     -0.029046
# payback30             0.050892  0.002246      0.033669      0.025432
# payback90             0.053776  0.002549      0.056822      0.050147
#
#                       rental30  rental90  last_rech_date_ma  \
# label                 0.057207  0.075869           0.004113
# aon                  -0.002930 -0.002618           0.001853
# daily_decr30          0.427503  0.444932          -0.000171
# daily_decr90          0.420561  0.457443           0.000058
# rental30              1.000000  0.955233          -0.000949
# rental90              0.955233  1.000000          -0.001758
# last_rech_date_ma    -0.000949 -0.001758           1.000000
# last_rech_date_da     0.003294  0.002643           0.002629
# last_rech_amt_ma      0.128773  0.123436          -0.000754
# cnt_ma_rech30         0.220472  0.218618           0.006491
# fr_ma_rech30          0.000272  0.001057          -0.001165
# sumamnt_ma_rech30     0.258656  0.246626           0.002544
# medianamnt_ma_rech30  0.132083  0.122747          -0.002716
# medianmarechprebal30 -0.001112 -0.001047           0.004216
# cnt_ma_rech90         0.295746  0.329330           0.006131
# fr_ma_rech90         -0.022353 -0.024882           0.000881
# sumamnt_ma_rech90     0.324302  0.342772           0.002345
# medianamnt_ma_rech90  0.113115  0.106832          -0.001947
# medianmarechprebal90  0.029945  0.032886          -0.001506
# cnt_da_rech30        -0.001286 -0.001307          -0.003344
# fr_da_rech30         -0.001917 -0.001997          -0.003469
# cnt_da_rech90         0.073169  0.057332          -0.003700
# fr_da_rech90          0.047579  0.037829          -0.002232
# cnt_loans30           0.162833  0.154900           0.002308
# amnt_loans30          0.217586  0.216641           0.001031
# maxamnt_loans30      -0.001525 -0.002189           0.001681
# medianamnt_loans30   -0.013746 -0.006703           0.002430
# cnt_loans90           0.003026  0.004301          -0.000216
# amnt_loans90          0.280233  0.307920           0.000664
# maxamnt_loans90       0.225449  0.241772          -0.003097
# medianamnt_loans90   -0.032555 -0.031045           0.003261
# payback30             0.075530  0.069847          -0.002857
# payback90             0.099533  0.104731          -0.001787
#
#                       last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# label                          0.001814          0.139969       0.244728  ...
# aon                           -0.001796          0.004102      -0.004315  ...
# daily_decr30                  -0.001311          0.287181       0.444365  ...
# daily_decr90                  -0.001484          0.275195       0.419650  ...
# rental30                       0.003294          0.128773       0.220472  ...
# rental90                       0.002643          0.123436       0.218618  ...
# last_rech_date_ma              0.002629         -0.000754       0.006491  ...
# last_rech_date_da              1.000000         -0.000699       0.002690  ...
# last_rech_amt_ma              -0.000699          1.000000       0.008012  ...
# cnt_ma_rech30                  0.002690          0.008012       1.000000  ...
# fr_ma_rech30                   0.000958          0.002998       0.002295  ...
# sumamnt_ma_rech30              0.000080          0.456707       0.646356  ...
# medianamnt_ma_rech30           0.000184          0.796969       0.002987  ...
# medianmarechprebal30           0.003673         -0.002597       0.000556  ...
# cnt_ma_rech90                  0.001924          0.028202       0.884131  ...
# fr_ma_rech90                   0.001071          0.109126      -0.130383  ...
# sumamnt_ma_rech90             -0.000296          0.436776       0.572447  ...
# medianamnt_ma_rech90          -0.000321          0.824654      -0.039974  ...
# medianmarechprebal90           0.004731          0.125195       0.018759  ...
# cnt_da_rech30                 -0.003807         -0.002644       0.003369  ...
# fr_da_rech30                   0.000455         -0.003196      -0.000292  ...
# cnt_da_rech90                 -0.001229          0.015274       0.011810  ...
# fr_da_rech90                   0.000210          0.016371       0.005453  ...
# cnt_loans30                    0.001722         -0.019892       0.733577  ...
# amnt_loans30                   0.001443          0.017706       0.723759  ...
# maxamnt_loans30                0.001135          0.000558      -0.001186  ...
# medianamnt_loans30             0.000009          0.029945      -0.058580  ...
# cnt_loans90                   -0.002355          0.000444       0.012307  ...
# amnt_loans90                   0.001179          0.024067       0.658939  ...
# maxamnt_loans90                0.002294          0.148656       0.180305  ...
# medianamnt_loans90            -0.002258          0.022939      -0.063378  ...
# payback30                     -0.000020         -0.026037       0.057166  ...
# payback90                      0.000699         -0.013236       0.031696  ...
#
#                       cnt_loans30  amnt_loans30  maxamnt_loans30  \
# label                    0.197565      0.199916        -0.000274
# aon                     -0.003157     -0.003302        -0.003096
# daily_decr30             0.346504      0.454169         0.001569
# daily_decr90             0.321006      0.430940         0.001283
# rental30                 0.162833      0.217586        -0.001525
# rental90                 0.154900      0.216641        -0.002189
# last_rech_date_ma        0.002308      0.001031         0.001681
# last_rech_date_da        0.001722      0.001443         0.001135
# last_rech_amt_ma        -0.019892      0.017706         0.000558
# cnt_ma_rech30            0.733577      0.723759        -0.001186
# fr_ma_rech30             0.003172      0.002860        -0.002389
# sumamnt_ma_rech30        0.461596      0.503819         0.001551
# medianamnt_ma_rech30    -0.019427      0.018799         0.002353
# medianmarechprebal30     0.000720      0.000802        -0.001916
# cnt_ma_rech90            0.657093      0.679860        -0.000981
# fr_ma_rech90            -0.095577     -0.101195         0.001455
# sumamnt_ma_rech90        0.412481      0.481843         0.001867
# medianamnt_ma_rech90    -0.052248     -0.015216         0.001287
# medianmarechprebal90    -0.040414     -0.030404         0.002022
# cnt_da_rech30            0.003343      0.002567        -0.002259
# fr_da_rech30            -0.000826     -0.001507        -0.000645
# cnt_da_rech90            0.018352      0.026531        -0.001474
# fr_da_rech90             0.007443      0.012066        -0.000409
# cnt_loans30              1.000000      0.956576        -0.000302
# amnt_loans30             0.956576      1.000000        -0.000240
# maxamnt_loans30         -0.000302     -0.000240         1.000000
# medianamnt_loans30      -0.087408     -0.071821         0.008336
# cnt_loans90              0.013875      0.013252         0.003364
# amnt_loans90             0.850820      0.896534        -0.001706
# maxamnt_loans90          0.150610      0.342611         0.000132
# medianamnt_loans90      -0.092829     -0.082189         0.009825
# payback30                0.086703      0.078025        -0.000741
# payback90                0.051928      0.048781        -0.000159
#
#                       medianamnt_loans30  cnt_loans90  amnt_loans90  \
# label                           0.050067     0.004305      0.205065
# aon                             0.004679     0.000192     -0.003336
# daily_decr30                   -0.005629     0.008865      0.542179
# daily_decr90                    0.000012     0.009220      0.544854
# rental30                       -0.013746     0.003026      0.280233
# rental90                       -0.006703     0.004301      0.307920
# last_rech_date_ma               0.002430    -0.000216      0.000664
# last_rech_date_da               0.000009    -0.002355      0.001179
# last_rech_amt_ma                0.029945     0.000444      0.024067
# cnt_ma_rech30                  -0.058580     0.012307      0.658939
# fr_ma_rech30                   -0.000416     0.003980      0.002794
# sumamnt_ma_rech30              -0.026794     0.008296      0.460148
# medianamnt_ma_rech30            0.033407    -0.000636      0.026795
# medianmarechprebal30           -0.002140     0.002095      0.001382
# cnt_ma_rech90                  -0.045644     0.013583      0.753304
# fr_ma_rech90                    0.019313    -0.002041     -0.109715
# sumamnt_ma_rech90              -0.014902     0.010786      0.533540
# medianamnt_ma_rech90            0.037270     0.000538     -0.013136
# medianmarechprebal90            0.030114    -0.000650     -0.033457
# cnt_da_rech30                  -0.000995    -0.001694      0.003354
# fr_da_rech30                   -0.001739    -0.003855      0.000602
# cnt_da_rech90                  -0.003062     0.001208      0.021544
# fr_da_rech90                   -0.002319     0.002682      0.008969
# cnt_loans30                    -0.087408     0.013875      0.850820
# amnt_loans30                   -0.071821     0.013252      0.896534
# maxamnt_loans30                 0.008336     0.003364     -0.001706
# medianamnt_loans30              1.000000    -0.002246     -0.061690
# cnt_loans90                    -0.002246     1.000000      0.015576
# amnt_loans90                   -0.061690     0.015576      1.000000
# maxamnt_loans90                 0.062114     0.001653      0.332799
# medianamnt_loans90              0.915271    -0.001256     -0.090813
# payback30                      -0.005404     0.000008      0.068102
# payback90                       0.003336    -0.000901      0.048437
#
#                       maxamnt_loans90  medianamnt_loans90  payback30  \
# label                        0.086033            0.041265   0.050892
# aon                         -0.000975            0.002346   0.002246
# daily_decr30                 0.396803           -0.031485   0.033669
# daily_decr90                 0.394487           -0.029046   0.025432
# rental30                     0.225449           -0.032555   0.075530
# rental90                     0.241772           -0.031045   0.069847
# last_rech_date_ma           -0.003097            0.003261  -0.002857
# last_rech_date_da            0.002294           -0.002258  -0.000020
# last_rech_amt_ma             0.148656            0.022939  -0.026037
# cnt_ma_rech30                0.180305           -0.063378   0.057166
# fr_ma_rech30                -0.001276           -0.001572   0.002473
# sumamnt_ma_rech30            0.260943           -0.034854   0.008018
# medianamnt_ma_rech30         0.160716            0.023826  -0.016644
# medianmarechprebal30        -0.002558           -0.002058   0.001593
# cnt_ma_rech90                0.248826           -0.064568   0.021222
# fr_ma_rech90                -0.038461            0.015097   0.037328
# sumamnt_ma_rech90            0.323032           -0.034848  -0.021271
# medianamnt_ma_rech90         0.135380            0.032597  -0.034525
# medianmarechprebal90         0.028135            0.032048  -0.030236
# cnt_da_rech30               -0.001141           -0.001589  -0.000655
# fr_da_rech30                -0.000945           -0.001692   0.001505
# cnt_da_rech90                0.036098           -0.002749   0.014265
# fr_da_rech90                 0.021811           -0.001325   0.000673
# cnt_loans30                  0.150610           -0.092829   0.086703
# amnt_loans30                 0.342611           -0.082189   0.078025
# maxamnt_loans30              0.000132            0.009825  -0.000741
# medianamnt_loans30           0.062114            0.915271  -0.005404
# cnt_loans90                  0.001653           -0.001256   0.000008
# amnt_loans90                 0.332799           -0.090813   0.068102
# maxamnt_loans90              1.000000            0.036631   0.015477
# medianamnt_loans90           0.036631            1.000000  -0.012944
# payback30                    0.015477           -0.012944   1.000000
# payback90                    0.033080           -0.010585   0.827801
#
#                       payback90
# label                  0.053776
# aon                    0.002549
# daily_decr30           0.056822
# daily_decr90           0.050147
# rental30               0.099533
# rental90               0.104731
# last_rech_date_ma     -0.001787
# last_rech_date_da      0.000699
# last_rech_amt_ma      -0.013236
# cnt_ma_rech30          0.031696
# fr_ma_rech30           0.002102
# sumamnt_ma_rech30     -0.003634
# medianamnt_ma_rech30  -0.001416
# medianmarechprebal30   0.001695
# cnt_ma_rech90          0.009319
# fr_ma_rech90           0.079096
# sumamnt_ma_rech90     -0.022272
# medianamnt_ma_rech90  -0.022386
# medianmarechprebal90  -0.029950
# cnt_da_rech30          0.000488
# fr_da_rech30          -0.001122
# cnt_da_rech90          0.024713
# fr_da_rech90           0.001550
# cnt_loans30            0.051928
# amnt_loans30           0.048781
# maxamnt_loans30       -0.000159
# medianamnt_loans30     0.003336
# cnt_loans90           -0.000901
# amnt_loans90           0.048437
# maxamnt_loans90        0.033080
# medianamnt_loans90    -0.010585
# payback30              0.827801
# payback90              1.000000
#
# [33 rows x 33 columns]

# %%
# Check correlation matrix with heatmap.
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, fmt = '.1f', cmap = 'Blues')
#sns.heatmap(df.corr(), cmap='coolwarm', annot=True, fmt='.1f', linewidths=.1)
plt.show()

# %%
# Dropping the columns which is highly correlated with each other do avoid multicolinearity problem.
df.drop(columns=['daily_decr30','rental30','amnt_loans30','medianamnt_loans30'],axis=1, inplace = True)

# %%
# Get the numbers of rows and columns.
df.shape
# Out:
# (186243, 31)

# %%
# Making the new column Day, Month and year from pdate column
df['pDay']=pd.to_datetime(df['pdate'],format='%Y/%m/%d').dt.day
df['pMonth']=pd.to_datetime(df['pdate'],format='%Y/%m/%d').dt.month
df['pYear']=pd.to_datetime(df['pdate'],format='%Y/%m/%d').dt.year

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr90  rental90  last_rech_date_ma  \
# 0      0  21408I70789  272.0   3065.150000    260.13                2.0
# 1      1  76462I70374  712.0  12124.750000   3691.26               20.0
# 2      1  17943I70372  535.0   1398.000000    900.13                3.0
# 3      1  55773I70781  241.0     21.228000    159.42               41.0
# 4      1  03813I82730  947.0    150.619333   1098.90                4.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                0.0              1539              2          21.0  ...
# 1                0.0              5787              1           0.0  ...
# 2                0.0              1539              1           0.0  ...
# 3                0.0               947              0           0.0  ...
# 4                0.0              2309              7           2.0  ...
#
#    cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0          2.0            12                6                 0.0  29.000000
# 1          1.0            12               12                 0.0   0.000000
# 2          1.0             6                6                 0.0   0.000000
# 3          2.0            12                6                 0.0   0.000000
# 4          7.0            42                6                 0.0   2.333333
#
#    payback90       pdate  pDay  pMonth  pYear
# 0  29.000000  2016-07-20    20       7   2016
# 1   0.000000  2016-08-10    10       8   2016
# 2   0.000000  2016-08-19    19       8   2016
# 3   0.000000  2016-06-06     6       6   2016
# 4   2.333333  2016-06-22    22       6   2016
#
# [5 rows x 34 columns]

# %%
# Checking the number of months 
df['pMonth'].unique()
# Out:
# array([7, 8, 6], dtype=int64)

# %%
# After fetching the data from pdate column now we are going to drop it because it has not any significant role.
df.drop(columns=['pdate'],axis=1, inplace = True)

# %%
# Seprate the categorical columns and Numerical columns
cat_df,num_df=[],[]

for i in df.columns:
    if df[i].dtype==object:
        cat_df.append(i)
    elif (df[i].dtypes=='int64') | (df[i].dtypes=='float64') | (df[i].dtypes=='int32'):
        num_df.append(i)
    else: continue
        
print('>>> Total Number of Feature::', df.shape[1])
print('>>> Number of categorical features::', len(cat_df))
print('>>> Number of Numerical Feature::', len(num_df))
# Out:
# >>> Total Number of Feature:: 33
# >>> Number of categorical features:: 1
# >>> Number of Numerical Feature:: 32

# %% [markdown]
# # Data Visualization:

# %%
# Checking the correlation with target variable
plt.figure(figsize=(16,8))
df.drop('label', axis=1).corrwith(df['label']).plot(kind='bar',grid=True)
plt.xticks(rotation='vertical')
plt.title("Correlation with target Variable that is label column",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Correlation with target Variable that is label column')

# %%
# Checking the number of Fraud cases.
sns.countplot(x='label', data=df, palette='magma')
plt.title('No of defaulter/Non-defaulter Case',fontsize=18)
plt.show()

print(df['label'].value_counts())
# Out:
# 1    160383
# 0     25860
# Name: label, dtype: int64

# %%
# Plotting the Histogram
df.hist(figsize=(20,20),color='g')
plt.show()

# %%
# Customer label according to Date.
plt.figure(figsize=(20,8))
sns.countplot(x="pDay", hue='label', data=df, palette='Set2')
plt.title("Customers label according to Date", fontsize=25)
plt.xlabel('Date')
plt.ylabel('Counting of Customers')
plt.show()

# %%
# Customer label according to Month.
plt.figure(figsize=(8,6))
sns.countplot(x="pMonth", hue='label', data=df, palette='rainbow')
plt.title("Customers label according to month", fontsize=25)
plt.xlabel('Month')
plt.ylabel('Counting of Customers')
plt.show()

# %%
# Checking skewness with distplot.
for col in df.describe().columns:
    sns.distplot(df[col],color='b')
    plt.show()

# %%
# Checking skewness value.
df.skew().sort_values(ascending=False)
# Out:
# medianmarechprebal90    43.576364
# fr_da_rech90            28.959851
# cnt_da_rech90           28.396293
# cnt_da_rech30           17.749485
# maxamnt_loans30         17.718074
# cnt_loans90             16.717192
# last_rech_date_ma       14.852116
# fr_ma_rech30            14.822224
# last_rech_date_da       14.781824
# fr_da_rech30            14.728609
# medianmarechprebal30    14.677544
# aon                     10.365026
# payback30                8.193009
# sumamnt_ma_rech30        7.134012
# payback90                6.763241
# sumamnt_ma_rech90        5.231693
# medianamnt_loans90       4.774958
# rental90                 4.530925
# daily_decr90             4.301490
# last_rech_amt_ma         3.830612
# medianamnt_ma_rech90     3.753115
# cnt_ma_rech90            3.558616
# medianamnt_ma_rech30     3.519213
# cnt_ma_rech30            3.471313
# amnt_loans90             3.165962
# cnt_loans30              2.737584
# fr_ma_rech90             2.250443
# maxamnt_loans90          1.650198
# pMonth                   0.351293
# pDay                     0.200706
# pYear                    0.000000
# label                   -2.088847
# dtype: float64

# %%
# Treating Skewness via square root method.
# for col in df.skew().index:
#     print(col)
#     if col in df.describe().columns:
#         if df[col].skew() > 0.55:
#             df[col]=np.sqrt(df[col])

# %%
# Checking skewness value after removing skewness.
df.skew().sort_values(ascending=False)
# Out:
# medianmarechprebal90    43.576364
# fr_da_rech90            28.959851
# cnt_da_rech90           28.396293
# cnt_da_rech30           17.749485
# maxamnt_loans30         17.718074
# cnt_loans90             16.717192
# last_rech_date_ma       14.852116
# fr_ma_rech30            14.822224
# last_rech_date_da       14.781824
# fr_da_rech30            14.728609
# medianmarechprebal30    14.677544
# aon                     10.365026
# payback30                8.193009
# sumamnt_ma_rech30        7.134012
# payback90                6.763241
# sumamnt_ma_rech90        5.231693
# medianamnt_loans90       4.774958
# rental90                 4.530925
# daily_decr90             4.301490
# last_rech_amt_ma         3.830612
# medianamnt_ma_rech90     3.753115
# cnt_ma_rech90            3.558616
# medianamnt_ma_rech30     3.519213
# cnt_ma_rech30            3.471313
# amnt_loans90             3.165962
# cnt_loans30              2.737584
# fr_ma_rech90             2.250443
# maxamnt_loans90          1.650198
# pMonth                   0.351293
# pDay                     0.200706
# pYear                    0.000000
# label                   -2.088847
# dtype: float64

# %%
# checking outliers with boxplot.
df.plot(kind='box', subplots=True, layout=(11,3), figsize=(15,25))
# Out:
# label                      AxesSubplot(0.125,0.821923;0.227941x0.0580769)
# aon                     AxesSubplot(0.398529,0.821923;0.227941x0.0580769)
# daily_decr90            AxesSubplot(0.672059,0.821923;0.227941x0.0580769)
# rental90                   AxesSubplot(0.125,0.752231;0.227941x0.0580769)
# last_rech_date_ma       AxesSubplot(0.398529,0.752231;0.227941x0.0580769)
# last_rech_date_da       AxesSubplot(0.672059,0.752231;0.227941x0.0580769)
# last_rech_amt_ma           AxesSubplot(0.125,0.682538;0.227941x0.0580769)
# cnt_ma_rech30           AxesSubplot(0.398529,0.682538;0.227941x0.0580769)
# fr_ma_rech30            AxesSubplot(0.672059,0.682538;0.227941x0.0580769)
# sumamnt_ma_rech30          AxesSubplot(0.125,0.612846;0.227941x0.0580769)
# medianamnt_ma_rech30    AxesSubplot(0.398529,0.612846;0.227941x0.0580769)
# medianmarechprebal30    AxesSubplot(0.672059,0.612846;0.227941x0.0580769)
# cnt_ma_rech90              AxesSubplot(0.125,0.543154;0.227941x0.0580769)
# fr_ma_rech90            AxesSubplot(0.398529,0.543154;0.227941x0.0580769)
# sumamnt_ma_rech90       AxesSubplot(0.672059,0.543154;0.227941x0.0580769)
# medianamnt_ma_rech90       AxesSubplot(0.125,0.473462;0.227941x0.0580769)
# medianmarechprebal90    AxesSubplot(0.398529,0.473462;0.227941x0.0580769)
# cnt_da_rech30           AxesSubplot(0.672059,0.473462;0.227941x0.0580769)
# fr_da_rech30               AxesSubplot(0.125,0.403769;0.227941x0.0580769)
# cnt_da_rech90           AxesSubplot(0.398529,0.403769;0.227941x0.0580769)
# fr_da_rech90            AxesSubplot(0.672059,0.403769;0.227941x0.0580769)
# cnt_loans30                AxesSubplot(0.125,0.334077;0.227941x0.0580769)
# maxamnt_loans30         AxesSubplot(0.398529,0.334077;0.227941x0.0580769)
# cnt_loans90             AxesSubplot(0.672059,0.334077;0.227941x0.0580769)
# amnt_loans90               AxesSubplot(0.125,0.264385;0.227941x0.0580769)
# maxamnt_loans90         AxesSubplot(0.398529,0.264385;0.227941x0.0580769)
# medianamnt_loans90      AxesSubplot(0.672059,0.264385;0.227941x0.0580769)
# payback30                  AxesSubplot(0.125,0.194692;0.227941x0.0580769)
# payback90               AxesSubplot(0.398529,0.194692;0.227941x0.0580769)
# pDay                    AxesSubplot(0.672059,0.194692;0.227941x0.0580769)
# pMonth                        AxesSubplot(0.125,0.125;0.227941x0.0580769)
# pYear                      AxesSubplot(0.398529,0.125;0.227941x0.0580769)
# dtype: object

# %%
# Plotting outliers
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize = (18, 10))
sns.boxplot(ax=ax1, x = 'label', y = 'last_rech_date_ma', hue = 'label', data = df)
sns.boxplot(ax=ax2, x = 'label', y = 'last_rech_date_da', hue = 'label', data = df)
sns.boxplot(ax=ax3, x = 'label', y = 'cnt_da_rech30', hue = 'label', data = df)
sns.boxplot(ax=ax4, x = 'label', y = 'fr_da_rech30', hue = 'label', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='fr_da_rech30'>

# %%
#Creating a copy of our dataset
df2=df1.copy()

#Dropping the object columns
df1.drop(columns=['msisdn','pdate'],axis=1,inplace=True)

# %%
# Lets quantify.
from scipy.stats import zscore
(np.abs(zscore(df1))<3).all()
# Out:
# label                    True
# aon                     False
# daily_decr30            False
# daily_decr90            False
# rental30                False
# rental90                False
# last_rech_date_ma       False
# last_rech_date_da       False
# last_rech_amt_ma        False
# cnt_ma_rech30           False
# fr_ma_rech30            False
# sumamnt_ma_rech30       False
# medianamnt_ma_rech30    False
# medianmarechprebal30    False
# cnt_ma_rech90           False
# fr_ma_rech90            False
# sumamnt_ma_rech90       False
# medianamnt_ma_rech90    False
# medianmarechprebal90    False
# cnt_da_rech30           False
# fr_da_rech30            False
# cnt_da_rech90           False
# fr_da_rech90            False
# cnt_loans30             False
# amnt_loans30            False
# maxamnt_loans30         False
# medianamnt_loans30      False
# cnt_loans90             False
# amnt_loans90            False
# maxamnt_loans90         False
# medianamnt_loans90      False
# payback30               False
# payback90               False
# dtype: bool

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
#            label       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0       2.647896  0.103577      0.252299      0.276346  0.573844  0.558583
# 1       0.377658  0.097764      0.731037      0.553380  0.231788  0.036020
# 2       0.377658  0.100102      0.432011      0.429033  0.416020  0.447674
# 3       0.377658  0.103986      0.581326      0.555125  0.587935  0.576036
# 4       0.377658  0.094660      0.567293      0.543274  0.369886  0.413227
# ...          ...       ...           ...           ...       ...       ...
# 209588  0.377658  0.101833      0.567157      0.543159  0.372140  0.414910
# 209589  0.377658  0.092969      0.579622      0.553686  0.223791  0.304144
# 209590  0.377658  0.093788      0.700790      0.533194  0.735567  0.937500
# 209591  0.377658  0.084289      0.770755      0.594558  0.529352  0.433039
# 209592  0.377658  0.086284      0.096744      0.141746  0.512620  0.494278
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                0.069637           0.069550          0.221637       0.464760
# 1                0.069303           0.069550          1.570178       0.699718
# 2                0.069619           0.069550          0.221637       0.699718
# 3                0.068914           0.069550          0.471344       0.934677
# 4                0.069600           0.069550          0.103151       0.710030
# ...                   ...                ...               ...            ...
# 209588           0.069656           0.069550          0.836664       0.229802
# 209589           0.069600           0.069550          0.544737       0.005156
# 209590           0.069619           0.069550          0.221637       0.240114
# 209591           0.069637           0.068838          0.544737       0.240114
# 209592           0.069433           0.069550          2.303692       0.464760
#
#         ...  cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 0       ...     0.297116      0.342470         0.063284            0.247794
# 1       ...     0.688582      0.342470         0.061871            0.247794
# 2       ...     0.688582      0.687700         0.063284            0.247794
# 3       ...     0.297116      0.342470         0.063284            0.247794
# 4       ...     1.660218      1.383682         0.063284            0.247794
# ...     ...          ...           ...              ...                 ...
# 209588  ...     0.297116      0.342470         0.063284            0.247794
# 209589  ...     0.094351      0.002761         0.063284            0.247794
# 209590  ...     0.485818      1.383682         0.061871            0.247794
# 209591  ...     0.297116      0.002761         0.061871            0.247794
# 209592  ...     0.297116      0.002761         0.061871            0.247794
#
#         cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 0          0.073493      0.439950         0.334212            0.229594
# 1          0.077941      0.439950         2.517690            0.229594
# 2          0.077941      0.666624         0.334212            0.229594
# 3          0.073493      0.439950         0.334212            0.229594
# 4          0.051250      0.693417         0.334212            0.229594
# ...             ...           ...              ...                 ...
# 209588     0.073493      0.439950         0.334212            0.229594
# 209589     0.069044      0.213277         0.334212            0.229594
# 209590     0.055699      1.146764         2.517690            0.229594
# 209591     0.069044      0.013396         2.517690            0.229594
# 209592     0.073493      0.213277         2.517690            0.229594
#
#         payback30  payback90
# 0        2.904700   2.394093
# 1        0.385630   0.419233
# 2        0.385630   0.419233
# 3        0.385630   0.419233
# 4        0.120890   0.192873
# ...           ...        ...
# 209588   0.272170   0.322221
# 209589   0.272170   0.322221
# 209590   0.068209   0.047356
# 209591   0.385630   0.599385
# 209592   0.385630   0.419233
#
# [209593 rows x 33 columns]

# %%
# detecting outliers.
from scipy.stats import zscore
z = np.abs(zscore(df1))
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([15, 15, 32, ..., 28, 26, 30], dtype=int64))

# %%
df1_new=df1[(z<3).all(axis=1)]

#Checking the shape
print(df1.shape,'\t\t',df1_new.shape)
# Out:
# (209593, 33) 		 (161465, 33)

# %%
df.isna().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr90            0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# maxamnt_loans30         0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pDay                    0
# pMonth                  0
# pYear                   0
# dtype: int64

# %%
#Converting the categorical data into numeric variables
# Transform Non numeric columns into Numeric columns

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for column in df.columns:
    if df[column].dtype==np.number:
        continue
    df[column]=le.fit_transform(df[column])

# %%
df.head()
# Out:
#    label  msisdn    aon  daily_decr90  rental90  last_rech_date_ma  \
# 0      0   40191  272.0   3065.150000    260.13                2.0
# 1      1  142291  712.0  12124.750000   3691.26               20.0
# 2      1   33594  535.0   1398.000000    900.13                3.0
# 3      1  104157  241.0     21.228000    159.42               41.0
# 4      1    6910  947.0    150.619333   1098.90                4.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                0.0                14              2          21.0  ...
# 1                0.0                38              1           0.0  ...
# 2                0.0                14              1           0.0  ...
# 3                0.0                10              0           0.0  ...
# 4                0.0                23              7           2.0  ...
#
#    maxamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0              6.0          2.0             2                1
# 1             12.0          1.0             2                2
# 2              6.0          1.0             1                1
# 3              6.0          2.0             2                1
# 4              6.0          7.0             7                1
#
#    medianamnt_loans90  payback30  payback90  pDay  pMonth  pYear
# 0                 0.0  29.000000  29.000000    19       1      0
# 1                 0.0   0.000000   0.000000     9       2      0
# 2                 0.0   0.000000   0.000000    18       2      0
# 3                 0.0   0.000000   0.000000     5       0      0
# 4                 0.0   2.333333   2.333333    21       0      0
#
# [5 rows x 33 columns]

# %%
#feature importance
#Splitting the data into x and y
x = df.drop(['label'], axis=1)

y = df['label']

# %%
# Scalling the data
from sklearn.preprocessing import StandardScaler

st = StandardScaler()
x = st.fit_transform(x)
x
# Out:
# array([[-0.98449283, -0.10377791, -0.25447802, ...,  0.66650703,
#          0.28076267,  0.        ],
#        [ 0.9145572 , -0.09797818,  0.62163549, ..., -0.51976436,
#          1.63266114,  0.        ],
#        [-1.10719639, -0.10031125, -0.41570066, ...,  0.54787989,
#          1.63266114,  0.        ],
#        ...,
#        [-0.93473809, -0.10203799, -0.53620811, ...,  0.31062561,
#         -1.07113581,  0.        ],
#        [ 0.33976442, -0.08453335,  0.66511624, ...,  1.25964272,
#          0.28076267,  0.        ],
#        [ 0.52343845, -0.08652371, -0.11235279, ..., -0.87564578,
#          0.28076267,  0.        ]])

# %%
# Splitting the data into training and testing data
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42,stratify=y)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
KNN = KNeighborsClassifier(n_neighbors=10)
LR = LogisticRegression()
DT = DecisionTreeClassifier(random_state=20)
GNB = GaussianNB()
RF = RandomForestClassifier()

# %%
models = []
models.append(('KNeighborsClassifier', KNN))
models.append(('LogisticRegression', LR))
models.append(('DecisionTreeClassifier',DT))
models.append(('GaussianNB', GNB))
models.append(('RandomForestClassifier', RF))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]

for name,model in models:
    print('****************************',name,'********************************')
    print('\n')
    
    Model.append(name)
    model.fit(x_train,y_train.values.ravel())
    print(model)
    
    pre=model.predict(x_test)
    print('\n')
    
    AS=accuracy_score(y_test,pre)
    print('Accuracy score = ', AS)
    score.append(AS*100)
    print('\n')
    
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_val_Score = ', sc)
    cvs.append(sc*100)
    print('\n')
    
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,pre)
    roc_auc= auc(false_positive_rate, true_positive_rate)
    print('roc_auc_score = ',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate, true_positive_rate, label = 'AUC= %0.2f'%roc_auc)
    plt.legend(loc='lower right')
    
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# **************************** KNeighborsClassifier ********************************
#
#
# KNeighborsClassifier(n_neighbors=10)
#
#
# Accuracy score =  0.8699025477194019
#
#
# Cross_val_Score =  0.8713937870453654
#
#
# roc_auc_score =  0.6867161965572931
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.54      0.43      0.48      5172
#            1       0.91      0.94      0.93     32077
#
#     accuracy                           0.87     37249
#    macro avg       0.73      0.69      0.70     37249
# weighted avg       0.86      0.87      0.86     37249
#
#
#
# [[ 2240  2932]
#  [ 1914 30163]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# **************************** LogisticRegression ********************************
#
#
# LogisticRegression()
#
#
# Accuracy score =  0.8642379661198958
#
#
# Cross_val_Score =  0.8642364984778247
#
#
# roc_auc_score =  0.5250645042510697
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.63      0.06      0.10      5172
#            1       0.87      0.99      0.93     32077
#
#     accuracy                           0.86     37249
#    macro avg       0.75      0.53      0.51     37249
# weighted avg       0.83      0.86      0.81     37249
#
#
#
# [[  287  4885]
#  [  172 31905]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# **************************** DecisionTreeClassifier ********************************
#
#
# DecisionTreeClassifier(random_state=20)
#
#
# Accuracy score =  0.8717549464415152
#
#
# Cross_val_Score =  0.8746583457298369
#
#
# roc_auc_score =  0.740822571393308
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.54      0.56      0.55      5172
#            1       0.93      0.92      0.93     32077
#
#     accuracy                           0.87     37249
#    macro avg       0.73      0.74      0.74     37249
# weighted avg       0.87      0.87      0.87     37249
#
#
#
# [[ 2894  2278]
#  [ 2499 29578]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# **************************** GaussianNB ********************************
#
#
# GaussianNB()
#
#
# Accuracy score =  0.6136272114687643
#
#
# Cross_val_Score =  0.6083770543601099
#
#
# roc_auc_score =  0.717201145874796
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.25      0.86      0.38      5172
#            1       0.96      0.57      0.72     32077
#
#     accuracy                           0.61     37249
#    macro avg       0.60      0.72      0.55     37249
# weighted avg       0.86      0.61      0.67     37249
#
#
#
# [[ 4451   721]
#  [13671 18406]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# **************************** RandomForestClassifier ********************************
#
#
# RandomForestClassifier()
#
#
# Accuracy score =  0.9137426508094177
#
#
# Cross_val_Score =  0.9135537864111256
#
#
# roc_auc_score =  0.7470379424162581
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.79      0.52      0.62      5172
#            1       0.93      0.98      0.95     32077
#
#     accuracy                           0.91     37249
#    macro avg       0.86      0.75      0.79     37249
# weighted avg       0.91      0.91      0.91     37249
#
#
#
# [[ 2670  2502]
#  [  711 31366]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)

# %%
result=pd.DataFrame({'Model': Model, 'Accuracy_score': score, 'Cross_val_score':cvs, 'Roc_auc_curve':rocscore})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score  Roc_auc_curve
# 0    KNeighborsClassifier       86.990255        87.139379      68.671620
# 1      LogisticRegression       86.423797        86.423650      52.506450
# 2  DecisionTreeClassifier       87.175495        87.465835      74.082257
# 3              GaussianNB       61.362721        60.837705      71.720115
# 4  RandomForestClassifier       91.374265        91.355379      74.703794

# %% [markdown]
# # Hypertuning of the model:

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
parameters = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = RF, param_distributions = parameters, scoring='neg_mean_squared_error', n_iter = 10, cv = 10, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.8min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 3.7min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time= 4.0min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.2min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.4min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.5min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.3min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.2min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.4min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.3min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 5.8min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 5.8min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time= 6.3min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time= 1.5min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.0min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.0min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.0min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.1min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=18.8min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.3min
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time= 2.3min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 3.9min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.2min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.3min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.4min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.3min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time= 4.5min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 7.0min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 7.3min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 7.1min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 6.9min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 6.5min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 6.4min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 6.3min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 6.4min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 6.3min
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 7.0min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.9min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.9min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time= 2.8min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 9.1min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.8min
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=300; total time= 1.9min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.1min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.2min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.4min
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time= 2.4min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 6.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 5.3min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 5.0min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.5min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.1min
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=700; total time= 4.1min
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
rfc = RandomForestClassifier(n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features='sqrt', max_depth=25)
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
pred_decision = rfc.predict(x_test)

rfca = accuracy_score(y_test,pred_decision)
print("Accuracy Score is:",rfca*100)

rfscore = cross_val_score(rfc,x,y,cv=10)
rfc = rfscore.mean()
print("Cross Val Score is:",rfc*100)

false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,pred_decision)
roc_auc= auc(false_positive_rate, true_positive_rate)
print('roc_auc_score = ',roc_auc)
rocscore.append(roc_auc*100)
print('\n')
# Out:
# Accuracy Score is: 91.46017342747457
# Cross Val Score is: 91.4074622339076
# roc_auc_score =  0.7460771778349182

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename = 'micro_credit_defaulter.pkl'
pickle.dump(rfc,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a = np.array(y_test)
#predicted = np.array(ls.predict(x_test))
df_comp = pd.DataFrame({'original':a,'predicted':pred_decision},index=range(len(a)))
df_comp
# Out:
#        original  predicted
# 0             1          1
# 1             1          1
# 2             1          1
# 3             1          1
# 4             1          1
# ...         ...        ...
# 37244         1          1
# 37245         1          1
# 37246         1          1
# 37247         1          1
# 37248         1          1
#
# [37249 rows x 2 columns]
